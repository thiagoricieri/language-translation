# %% [markdown]
# # Language Translation
# In this project, you’re going to take a peek into the realm of neural network machine translation.  You’ll be training a sequence to sequence model on a dataset of English and French sentences that can translate new sentences from English to French.
# ## Get the Data
# Since translating the whole language of English to French will take lots of time to train, we have provided you with a small portion of the English corpus.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import helper
import problem_unittests as tests

source_path = 'data/small_vocab_en'
target_path = 'data/small_vocab_fr'
source_text = helper.load_data(source_path)
target_text = helper.load_data(target_path)

# %% [markdown]
# ## Explore the Data
# Play around with view_sentence_range to view different parts of the data.

# %%
view_sentence_range = (0, 10)

"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import numpy as np

print('Dataset Stats')
print('Roughly the number of unique words: {}'.format(len({word: None for word in source_text.split()})))

sentences = source_text.split('\n')
word_counts = [len(sentence.split()) for sentence in sentences]
print('Number of sentences: {}'.format(len(sentences)))
print('Average number of words in a sentence: {}'.format(np.average(word_counts)))

print()
print('English sentences {} to {}:'.format(*view_sentence_range))
print('\n'.join(source_text.split('\n')[view_sentence_range[0]:view_sentence_range[1]]))
print()
print('French sentences {} to {}:'.format(*view_sentence_range))
print('\n'.join(target_text.split('\n')[view_sentence_range[0]:view_sentence_range[1]]))
# Out:
# Dataset Stats
# Roughly the number of unique words: 227
# Number of sentences: 137861
# Average number of words in a sentence: 13.225277634719028
#
# English sentences 0 to 10:
# new jersey is sometimes quiet during autumn , and it is snowy in april .
# the united states is usually chilly during july , and it is usually freezing in november .
# california is usually quiet during march , and it is usually hot in june .
# the united states is sometimes mild during june , and it is cold in september .
# your least liked fruit is the grape , but my least liked is the apple .
# his favorite fruit is the orange , but my favorite is the grape .
# paris is relaxing during december , but it is usually chilly in july .
# new jersey is busy during spring , and it is never hot in march .
# our least liked fruit is the lemon , but my least liked is the grape .
# the united states is sometimes busy during january , and it is sometimes warm in november .
#
# French sentences 0 to 10:
# new jersey est parfois calme pendant l' automne , et il est neigeux en avril .
# les états-unis est généralement froid en juillet , et il gèle habituellement en novembre .
# california est généralement calme en mars , et il est généralement chaud en juin .
# les états-unis est parfois légère en juin , et il fait froid en septembre .
# votre moins aimé fruit est le raisin , mais mon moins aimé est la pomme .
# son fruit préféré est l'orange , mais mon préféré est le raisin .
# paris est relaxant en décembre , mais il est généralement froid en juillet .
# new jersey est occupé au printemps , et il est jamais chaude en mars .
# notre fruit est moins aimé le citron , mais mon moins aimé est le raisin .
# les états-unis est parfois occupé en janvier , et il est parfois chaud en novembre .

# %% [markdown]
# ## Implement Preprocessing Function
# ### Text to Word Ids
# As you did with other RNNs, you must turn the text into a number so the computer can understand it. In the function `text_to_ids()`, you'll turn `source_text` and `target_text` from words to ids.  However, you need to add the `<EOS>` word id at the end of `target_text`.  This will help the neural network predict when the sentence should end.
#
# You can get the `<EOS>` word id by doing:
# ```python
# target_vocab_to_int['<EOS>']
# ```
# You can get other word ids using `source_vocab_to_int` and `target_vocab_to_int`.

# %%
import re

def text_to_ids(source_text, target_text, source_vocab_to_int, target_vocab_to_int):
    """
    Convert source and target text to proper word ids
    :param source_text: String that contains all the source text.
    :param target_text: String that contains all the target text.
    :param source_vocab_to_int: Dictionary to go from the source words to an id
    :param target_vocab_to_int: Dictionary to go from the target words to an id
    :return: A tuple of lists (source_id_text, target_id_text)
    """
    
    st = source_text
    svti = source_vocab_to_int
    source_ints = []
    for line in st.split("\n"):
        source_ints.append([svti[w] for w in line.split()])
    
    tt = target_text
    tvti = target_vocab_to_int
    teos = target_vocab_to_int["<EOS>"]
    target_ints = []
    for line in tt.split("\n"):
        target_ints.append([tvti[w] for w in line.split()] + [teos])
        
    return (source_ints, target_ints)

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_text_to_ids(text_to_ids)
# Out:
# Tests Passed

# %% [markdown]
# ### Preprocess all the data and save it
# Running the code cell below will preprocess all the data and save it to file.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
helper.preprocess_and_save_data(source_path, target_path, text_to_ids)

# %% [markdown]
# # Check Point
# This is your first checkpoint. If you ever decide to come back to this notebook or have to restart the notebook, you can start from here. The preprocessed data has been saved to disk.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import numpy as np
import helper
import problem_unittests as tests

(source_int_text, target_int_text), (source_vocab_to_int, target_vocab_to_int), _ = helper.load_preprocess()

# %% [markdown]
# ### Check the Version of TensorFlow and Access to GPU
# This will check to make sure you have the correct version of TensorFlow and access to a GPU

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
from distutils.version import LooseVersion
import warnings
import tensorflow as tf
from tensorflow.python.layers.core import Dense

# Check TensorFlow Version
assert LooseVersion(tf.__version__) >= LooseVersion('1.1'), 'Please use TensorFlow version 1.1 or newer'
print('TensorFlow Version: {}'.format(tf.__version__))

# Check for a GPU
if not tf.test.gpu_device_name():
    warnings.warn('No GPU found. Please use a GPU to train your neural network.')
else:
    print('Default GPU Device: {}'.format(tf.test.gpu_device_name()))
# Out:
# TensorFlow Version: 1.3.0
# /Users/thiagoricieri/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:15: UserWarning: No GPU found. Please use a GPU to train your neural network.
#   from ipykernel import kernelapp as app

# %% [markdown]
# ## Build the Neural Network
# You'll build the components necessary to build a Sequence-to-Sequence model by implementing the following functions below:
# - `model_inputs`
# - `process_decoder_input`
# - `encoding_layer`
# - `decoding_layer_train`
# - `decoding_layer_infer`
# - `decoding_layer`
# - `seq2seq_model`
#
# ### Input
# Implement the `model_inputs()` function to create TF Placeholders for the Neural Network. It should create the following placeholders:
#
# - Input text placeholder named "input" using the TF Placeholder name parameter with rank 2.
# - Targets placeholder with rank 2.
# - Learning rate placeholder with rank 0.
# - Keep probability placeholder named "keep_prob" using the TF Placeholder name parameter with rank 0.
# - Target sequence length placeholder named "target_sequence_length" with rank 1
# - Max target sequence length tensor named "max_target_len" getting its value from applying tf.reduce_max on the target_sequence_length placeholder. Rank 0.
# - Source sequence length placeholder named "source_sequence_length" with rank 1
#
# Return the placeholders in the following the tuple (input, targets, learning rate, keep probability, target sequence length, max target sequence length, source sequence length)

# %%
def model_inputs():
    """
    Create TF Placeholders for input, targets, learning rate, and lengths of source and target sequences.
    :return: Tuple (input, targets, learning rate, keep probability, target sequence length,
    max target sequence length, source sequence length)
    """
    tensor = tf.placeholder(tf.int32, shape=[None, None], name='input')
    targets = tf.placeholder(tf.int32, shape=[None, None], name='targets')
    learning_rate = tf.placeholder(tf.float32, shape=[], name='learning_rate')
    keep_prob = tf.placeholder(tf.float32, shape=[], name='keep_prob')
    target_sequence_length = tf.placeholder(tf.int32, [None,], name='target_sequence_length')
    max_target_length = tf.reduce_max(target_sequence_length)
    source_sequence_length = tf.placeholder(tf.int32, [None,], name='source_sequence_length')
    
    return (tensor, 
            targets, 
            learning_rate, 
            keep_prob, 
            target_sequence_length, 
            max_target_length, 
            source_sequence_length)

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_model_inputs(model_inputs)
# Out:
# Tests Passed

# %% [markdown]
# ### Process Decoder Input
# Implement `process_decoder_input` by removing the last word id from each batch in `target_data` and concat the GO ID to the begining of each batch.

# %%
def process_decoder_input(target_data, target_vocab_to_int, batch_size):
    """
    Preprocess target data for encoding
    :param target_data: Target Placehoder
    :param target_vocab_to_int: Dictionary to go from the target words to an id
    :param batch_size: Batch Size
    :return: Preprocessed target data
    """
    ending = tf.strided_slice(target_data, [0,0], [batch_size, -1], [1,1])
    teos = target_vocab_to_int['<GO>']
    tfill = tf.fill([batch_size, 1], teos)
    decoder_input = tf.concat([tfill, ending], 1)
    return decoder_input

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_process_encoding_input(process_decoder_input)
# Out:
# Tests Passed

# %% [markdown]
# ### Encoding
# Implement `encoding_layer()` to create a Encoder RNN layer:
#  * Embed the encoder input using [`tf.contrib.layers.embed_sequence`](https://www.tensorflow.org/api_docs/python/tf/contrib/layers/embed_sequence)
#  * Construct a [stacked](https://github.com/tensorflow/tensorflow/blob/6947f65a374ebf29e74bb71e36fd82760056d82c/tensorflow/docs_src/tutorials/recurrent.md#stacking-multiple-lstms) [`tf.contrib.rnn.LSTMCell`](https://www.tensorflow.org/api_docs/python/tf/contrib/rnn/LSTMCell) wrapped in a [`tf.contrib.rnn.DropoutWrapper`](https://www.tensorflow.org/api_docs/python/tf/contrib/rnn/DropoutWrapper)
#  * Pass cell and embedded input to [`tf.nn.dynamic_rnn()`](https://www.tensorflow.org/api_docs/python/tf/nn/dynamic_rnn)

# %%
from imp import reload
from tensorflow import random_uniform_initializer
from tensorflow.contrib.layers import embed_sequence
from tensorflow.contrib.rnn import LSTMCell, DropoutWrapper, MultiRNNCell

reload(tests)

def encoding_layer(rnn_inputs, rnn_size, num_layers, keep_prob, 
                   source_sequence_length, source_vocab_size, 
                   encoding_embedding_size):
    """
    Create encoding layer
    :param rnn_inputs: Inputs for the RNN
    :param rnn_size: RNN Size
    :param num_layers: Number of layers
    :param keep_prob: Dropout keep probability
    :param source_sequence_length: a list of the lengths of each sequence in the batch
    :param source_vocab_size: vocabulary size of source data
    :param encoding_embedding_size: embedding size of source data
    :return: tuple (RNN output, RNN state)
    """
    encoding_embed = embed_sequence(
        rnn_inputs, 
        source_vocab_size, 
        encoding_embedding_size
    )
    
    cells = []
    for _ in range(num_layers):
        init = random_uniform_initializer(-0.1, 0.1, seed=2)
        lstm_cell = LSTMCell(rnn_size, initializer=init)
        drop_wrapped_cell = DropoutWrapper(lstm_cell, output_keep_prob=keep_prob)
        cells.append(drop_wrapped_cell)
    
    encoded_cell = MultiRNNCell(cells)
    encoding_output, encoding_state = tf.nn.dynamic_rnn(encoded_cell, 
                                                  encoding_embed, 
                                                  sequence_length=source_sequence_length,
                                                  dtype=tf.float32)
    
    return encoding_output, encoding_state

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_encoding_layer(encoding_layer)
# Out:
# Tests Passed

# %% [markdown]
# ### Decoding - Training
# Create a training decoding layer:
# * Create a [`tf.contrib.seq2seq.TrainingHelper`](https://www.tensorflow.org/api_docs/python/tf/contrib/seq2seq/TrainingHelper)
# * Create a [`tf.contrib.seq2seq.BasicDecoder`](https://www.tensorflow.org/api_docs/python/tf/contrib/seq2seq/BasicDecoder)
# * Obtain the decoder outputs from [`tf.contrib.seq2seq.dynamic_decode`](https://www.tensorflow.org/api_docs/python/tf/contrib/seq2seq/dynamic_decode)

# %%
from tensorflow.contrib.seq2seq import TrainingHelper, BasicDecoder, dynamic_decode

def decoding_layer_train(encoder_state, dec_cell, dec_embed_input, 
                         target_sequence_length, max_summary_length, 
                         output_layer, keep_prob):
    """
    Create a decoding layer for training
    :param encoder_state: Encoder State
    :param dec_cell: Decoder RNN Cell
    :param dec_embed_input: Decoder embedded input
    :param target_sequence_length: The lengths of each sequence in the target batch
    :param max_summary_length: The length of the longest sequence in the batch
    :param output_layer: Function to apply the output layer
    :param keep_prob: Dropout keep probability
    :return: BasicDecoderOutput containing training logits and sample_id
    """
    training_helper = TrainingHelper(
        inputs=dec_embed_input,
        sequence_length=target_sequence_length,
        time_major=False
    )
    
    training_decoder = BasicDecoder(
        dec_cell, 
        training_helper, 
        encoder_state, 
        output_layer
    )
    
    training_decoder_output = dynamic_decode(
        training_decoder,
        impute_finished=True,
        maximum_iterations=max_summary_length
    )
    
    first_output = training_decoder_output[0]
    return first_output

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_decoding_layer_train(decoding_layer_train)
# Out:
# Tests Passed

# %% [markdown]
# ### Decoding - Inference
# Create inference decoder:
# * Create a [`tf.contrib.seq2seq.GreedyEmbeddingHelper`](https://www.tensorflow.org/api_docs/python/tf/contrib/seq2seq/GreedyEmbeddingHelper)
# * Create a [`tf.contrib.seq2seq.BasicDecoder`](https://www.tensorflow.org/api_docs/python/tf/contrib/seq2seq/BasicDecoder)
# * Obtain the decoder outputs from [`tf.contrib.seq2seq.dynamic_decode`](https://www.tensorflow.org/api_docs/python/tf/contrib/seq2seq/dynamic_decode)

# %%
from tensorflow.contrib.seq2seq import GreedyEmbeddingHelper, BasicDecoder, dynamic_decode

def decoding_layer_infer(encoder_state, dec_cell, dec_embeddings, start_of_sequence_id,
                         end_of_sequence_id, max_target_sequence_length,
                         vocab_size, output_layer, batch_size, keep_prob):
    """
    Create a decoding layer for inference
    :param encoder_state: Encoder state
    :param dec_cell: Decoder RNN Cell
    :param dec_embeddings: Decoder embeddings
    :param start_of_sequence_id: GO ID
    :param end_of_sequence_id: EOS Id
    :param max_target_sequence_length: Maximum length of target sequences
    :param vocab_size: Size of decoder/target vocabulary
    :param decoding_scope: TenorFlow Variable Scope for decoding
    :param output_layer: Function to apply the output layer
    :param batch_size: Batch size
    :param keep_prob: Dropout keep probability
    :return: BasicDecoderOutput containing inference logits and sample_id
    """
    constant = tf.constant([start_of_sequence_id], dtype=tf.int32)
    start_tokens = tf.tile(constant, [batch_size], name='start_tokens')

    inference_helper = GreedyEmbeddingHelper(
        dec_embeddings,
        start_tokens,
        end_of_sequence_id
    )
    
    inference_decoder = BasicDecoder(
        dec_cell,
        inference_helper,
        encoder_state,
        output_layer
    )
    
    inference_decoder_output = dynamic_decode(
        inference_decoder,
        impute_finished=True,
        maximum_iterations=max_target_sequence_length
    )
    
    first_inference_decoder = inference_decoder_output[0]
    return first_inference_decoder

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_decoding_layer_infer(decoding_layer_infer)
# Out:
# Tests Passed

# %% [markdown]
# ### Build the Decoding Layer
# Implement `decoding_layer()` to create a Decoder RNN layer.
#
# * Embed the target sequences
# * Construct the decoder LSTM cell (just like you constructed the encoder cell above)
# * Create an output layer to map the outputs of the decoder to the elements of our vocabulary
# * Use the your `decoding_layer_train(encoder_state, dec_cell, dec_embed_input, target_sequence_length, max_target_sequence_length, output_layer, keep_prob)` function to get the training logits.
# * Use your `decoding_layer_infer(encoder_state, dec_cell, dec_embeddings, start_of_sequence_id, end_of_sequence_id, max_target_sequence_length, vocab_size, output_layer, batch_size, keep_prob)` function to get the inference logits.
#
# Note: You'll need to use [tf.variable_scope](https://www.tensorflow.org/api_docs/python/tf/variable_scope) to share variables between training and inference.

# %%
from tensorflow.contrib.rnn import LSTMCell, DropoutWrapper, MultiRNNCell

def decoding_layer(dec_input, encoder_state,
                   target_sequence_length, max_target_sequence_length,
                   rnn_size,
                   num_layers, target_vocab_to_int, target_vocab_size,
                   batch_size, keep_prob, decoding_embedding_size):
    """
    Create decoding layer
    :param dec_input: Decoder input
    :param encoder_state: Encoder state
    :param target_sequence_length: The lengths of each sequence in the target batch
    :param max_target_sequence_length: Maximum length of target sequences
    :param rnn_size: RNN Size
    :param num_layers: Number of layers
    :param target_vocab_to_int: Dictionary to go from the target words to an id
    :param target_vocab_size: Size of target vocabulary
    :param batch_size: The size of the batch
    :param keep_prob: Dropout keep probability
    :param decoding_embedding_size: Decoding embedding size
    :return: Tuple of (Training BasicDecoderOutput, Inference BasicDecoderOutput)
    """
    random_uniform = tf.random_uniform([target_vocab_size, decoding_embedding_size])
    decode_embeddings = tf.Variable(random_uniform)
    decode_embed_input = tf.nn.embedding_lookup(decode_embeddings, dec_input)
    
    cells = []
    for _ in range(num_layers):
        init = tf.random_uniform_initializer(-0.1, 0.1, seed=2)
        lstm_cell = LSTMCell(rnn_size, initializer=init)
        drop_wrapped_cell = DropoutWrapper(lstm_cell, output_keep_prob=keep_prob)
        cells.append(drop_wrapped_cell)

    decode_cell = MultiRNNCell(cells)
    
    output_init = tf.truncated_normal_initializer(mean=0.0, stddev=0.1)
    output_layer = Dense(target_vocab_size, kernel_initializer=output_init)

    with tf.variable_scope("decode"):
        train_decoder_out = decoding_layer_train(
            encoder_state, 
            decode_cell, 
            decode_embed_input, 
            target_sequence_length, 
            max_target_sequence_length, 
            output_layer, 
            keep_prob
        )
        
    with tf.variable_scope("decode", reuse=True):
        tgo = target_vocab_to_int['<GO>']
        teos = target_vocab_to_int['<EOS>']
        infer_decoder_out = decoding_layer_infer(
            encoder_state, 
            decode_cell, 
            decode_embeddings, 
            tgo, 
            teos, 
            max_target_sequence_length, 
            target_vocab_size, 
            output_layer, 
            batch_size, 
            keep_prob
        )
        
    return train_decoder_out, infer_decoder_out

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_decoding_layer(decoding_layer)
# Out:
# Tests Passed

# %% [markdown]
# ### Build the Neural Network
# Apply the functions you implemented above to:
#
# - Encode the input using your `encoding_layer(rnn_inputs, rnn_size, num_layers, keep_prob,  source_sequence_length, source_vocab_size, encoding_embedding_size)`.
# - Process target data using your `process_decoder_input(target_data, target_vocab_to_int, batch_size)` function.
# - Decode the encoded input using your `decoding_layer(dec_input, enc_state, target_sequence_length, max_target_sentence_length, rnn_size, num_layers, target_vocab_to_int, target_vocab_size, batch_size, keep_prob, dec_embedding_size)` function.

# %%
def seq2seq_model(input_data, target_data, keep_prob, batch_size,
                  source_sequence_length, target_sequence_length,
                  max_target_sentence_length,
                  source_vocab_size, target_vocab_size,
                  enc_embedding_size, dec_embedding_size,
                  rnn_size, num_layers, target_vocab_to_int):
    """
    Build the Sequence-to-Sequence part of the neural network
    :param input_data: Input placeholder
    :param target_data: Target placeholder
    :param keep_prob: Dropout keep probability placeholder
    :param batch_size: Batch Size
    :param source_sequence_length: Sequence Lengths of source sequences in the batch
    :param target_sequence_length: Sequence Lengths of target sequences in the batch
    :param source_vocab_size: Source vocabulary size
    :param target_vocab_size: Target vocabulary size
    :param enc_embedding_size: Decoder embedding size
    :param dec_embedding_size: Encoder embedding size
    :param rnn_size: RNN Size
    :param num_layers: Number of layers
    :param target_vocab_to_int: Dictionary to go from the target words to an id
    :return: Tuple of (Training BasicDecoderOutput, Inference BasicDecoderOutput)
    """
    _whocares, enc_state = encoding_layer(
        input_data, 
        rnn_size, 
        num_layers, 
        keep_prob, 
        source_sequence_length, 
        source_vocab_size, 
        enc_embedding_size
    )
    
    dec_input = process_decoder_input(
        target_data, 
        target_vocab_to_int, 
        batch_size
    )
    
    training_decoder_output, inference_decoder_output = decoding_layer(
        dec_input, 
        enc_state,
        target_sequence_length, 
        max_target_sentence_length,
        rnn_size,
        num_layers, 
        target_vocab_to_int, 
        target_vocab_size,
        batch_size, 
        keep_prob, 
        dec_embedding_size
    )
    
    return training_decoder_output, inference_decoder_output


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_seq2seq_model(seq2seq_model)
# Out:
# Tests Passed

# %% [markdown]
# ## Neural Network Training
# ### Hyperparameters
# Tune the following parameters:
#
# - Set `epochs` to the number of epochs.
# - Set `batch_size` to the batch size.
# - Set `rnn_size` to the size of the RNNs.
# - Set `num_layers` to the number of layers.
# - Set `encoding_embedding_size` to the size of the embedding for the encoder.
# - Set `decoding_embedding_size` to the size of the embedding for the decoder.
# - Set `learning_rate` to the learning rate.
# - Set `keep_probability` to the Dropout keep probability
# - Set `display_step` to state how many steps between each debug output statement

# %%
# Number of Epochs
epochs = 10
# Batch Size
batch_size = 256
# RNN Size
rnn_size = 512
# Number of Layers
num_layers = 2
# Embedding Size
encoding_embedding_size = 256
decoding_embedding_size = 256
# Learning Rate
learning_rate = 0.001
# Dropout Keep Probability
keep_probability = 0.75
display_step = 10

# %% [markdown]
# ### Build the Graph
# Build the graph using the neural network you implemented.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
save_path = 'checkpoints/dev'
(source_int_text, target_int_text), (source_vocab_to_int, target_vocab_to_int), _ = helper.load_preprocess()
max_target_sentence_length = max([len(sentence) for sentence in source_int_text])

train_graph = tf.Graph()
with train_graph.as_default():
    input_data, targets, lr, keep_prob, target_sequence_length, max_target_sequence_length, source_sequence_length = model_inputs()

    #sequence_length = tf.placeholder_with_default(max_target_sentence_length, None, name='sequence_length')
    input_shape = tf.shape(input_data)

    train_logits, inference_logits = seq2seq_model(tf.reverse(input_data, [-1]),
                                                   targets,
                                                   keep_prob,
                                                   batch_size,
                                                   source_sequence_length,
                                                   target_sequence_length,
                                                   max_target_sequence_length,
                                                   len(source_vocab_to_int),
                                                   len(target_vocab_to_int),
                                                   encoding_embedding_size,
                                                   decoding_embedding_size,
                                                   rnn_size,
                                                   num_layers,
                                                   target_vocab_to_int)


    training_logits = tf.identity(train_logits.rnn_output, name='logits')
    inference_logits = tf.identity(inference_logits.sample_id, name='predictions')

    masks = tf.sequence_mask(target_sequence_length, max_target_sequence_length, dtype=tf.float32, name='masks')

    with tf.name_scope("optimization"):
        # Loss function
        cost = tf.contrib.seq2seq.sequence_loss(
            training_logits,
            targets,
            masks)

        # Optimizer
        optimizer = tf.train.AdamOptimizer(lr)

        # Gradient Clipping
        gradients = optimizer.compute_gradients(cost)
        capped_gradients = [(tf.clip_by_value(grad, -1., 1.), var) for grad, var in gradients if grad is not None]
        train_op = optimizer.apply_gradients(capped_gradients)

# %% [markdown]
# Batch and pad the source and target sequences

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
def pad_sentence_batch(sentence_batch, pad_int):
    """Pad sentences with <PAD> so that each sentence of a batch has the same length"""
    max_sentence = max([len(sentence) for sentence in sentence_batch])
    return [sentence + [pad_int] * (max_sentence - len(sentence)) for sentence in sentence_batch]


def get_batches(sources, targets, batch_size, source_pad_int, target_pad_int):
    """Batch targets, sources, and the lengths of their sentences together"""
    for batch_i in range(0, len(sources)//batch_size):
        start_i = batch_i * batch_size

        # Slice the right amount for the batch
        sources_batch = sources[start_i:start_i + batch_size]
        targets_batch = targets[start_i:start_i + batch_size]

        # Pad
        pad_sources_batch = np.array(pad_sentence_batch(sources_batch, source_pad_int))
        pad_targets_batch = np.array(pad_sentence_batch(targets_batch, target_pad_int))

        # Need the lengths for the _lengths parameters
        pad_targets_lengths = []
        for target in pad_targets_batch:
            pad_targets_lengths.append(len(target))

        pad_source_lengths = []
        for source in pad_sources_batch:
            pad_source_lengths.append(len(source))

        yield pad_sources_batch, pad_targets_batch, pad_source_lengths, pad_targets_lengths

# %% [markdown]
# ### Train
# Train the neural network on the preprocessed data. If you have a hard time getting a good loss, check the forms to see if anyone is having the same problem.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
def get_accuracy(target, logits):
    """
    Calculate accuracy
    """
    max_seq = max(target.shape[1], logits.shape[1])
    if max_seq - target.shape[1]:
        target = np.pad(
            target,
            [(0,0),(0,max_seq - target.shape[1])],
            'constant')
    if max_seq - logits.shape[1]:
        logits = np.pad(
            logits,
            [(0,0),(0,max_seq - logits.shape[1])],
            'constant')

    return np.mean(np.equal(target, logits))

# Split data to training and validation sets
train_source = source_int_text[batch_size:]
train_target = target_int_text[batch_size:]
valid_source = source_int_text[:batch_size]
valid_target = target_int_text[:batch_size]
(valid_sources_batch, valid_targets_batch, valid_sources_lengths, valid_targets_lengths ) = next(get_batches(valid_source,
                                                                                                             valid_target,
                                                                                                             batch_size,
                                                                                                             source_vocab_to_int['<PAD>'],
                                                                                                             target_vocab_to_int['<PAD>']))                                                                                                  
with tf.Session(graph=train_graph) as sess:
    sess.run(tf.global_variables_initializer())

    for epoch_i in range(epochs):
        for batch_i, (source_batch, target_batch, sources_lengths, targets_lengths) in enumerate(
                get_batches(train_source, train_target, batch_size,
                            source_vocab_to_int['<PAD>'],
                            target_vocab_to_int['<PAD>'])):

            _, loss = sess.run(
                [train_op, cost],
                {input_data: source_batch,
                 targets: target_batch,
                 lr: learning_rate,
                 target_sequence_length: targets_lengths,
                 source_sequence_length: sources_lengths,
                 keep_prob: keep_probability})


            if batch_i % display_step == 0 and batch_i > 0:


                batch_train_logits = sess.run(
                    inference_logits,
                    {input_data: source_batch,
                     source_sequence_length: sources_lengths,
                     target_sequence_length: targets_lengths,
                     keep_prob: 1.0})


                batch_valid_logits = sess.run(
                    inference_logits,
                    {input_data: valid_sources_batch,
                     source_sequence_length: valid_sources_lengths,
                     target_sequence_length: valid_targets_lengths,
                     keep_prob: 1.0})

                train_acc = get_accuracy(target_batch, batch_train_logits)

                valid_acc = get_accuracy(valid_targets_batch, batch_valid_logits)

                print('Epoch {:>3} Batch {:>4}/{} - Train Accuracy: {:>6.4f}, Validation Accuracy: {:>6.4f}, Loss: {:>6.4f}'
                      .format(epoch_i, batch_i, len(source_int_text) // batch_size, train_acc, valid_acc, loss))

    # Save Model
    saver = tf.train.Saver()
    saver.save(sess, save_path)
    print('Model Trained and Saved')
# Out:
# Epoch   0 Batch   10/538 - Train Accuracy: 0.3320, Validation Accuracy: 0.4093, Loss: 3.2725
# Epoch   0 Batch   20/538 - Train Accuracy: 0.4293, Validation Accuracy: 0.4583, Loss: 2.5949
# Epoch   0 Batch   30/538 - Train Accuracy: 0.4271, Validation Accuracy: 0.4851, Loss: 2.4366
# Epoch   0 Batch   40/538 - Train Accuracy: 0.5066, Validation Accuracy: 0.5078, Loss: 1.9611
# Epoch   0 Batch   50/538 - Train Accuracy: 0.4434, Validation Accuracy: 0.4995, Loss: 1.8775
# Epoch   0 Batch   60/538 - Train Accuracy: 0.4129, Validation Accuracy: 0.4725, Loss: 1.6920
# Epoch   0 Batch   70/538 - Train Accuracy: 0.4738, Validation Accuracy: 0.5124, Loss: 1.4755
# Epoch   0 Batch   80/538 - Train Accuracy: 0.4328, Validation Accuracy: 0.4860, Loss: 1.4481
# Epoch   0 Batch   90/538 - Train Accuracy: 0.4593, Validation Accuracy: 0.4812, Loss: 1.2804
# Epoch   0 Batch  100/538 - Train Accuracy: 0.5156, Validation Accuracy: 0.5384, Loss: 1.1752
# Epoch   0 Batch  110/538 - Train Accuracy: 0.4895, Validation Accuracy: 0.5298, Loss: 1.1509
# Epoch   0 Batch  120/538 - Train Accuracy: 0.5363, Validation Accuracy: 0.5522, Loss: 1.0050
# Epoch   0 Batch  130/538 - Train Accuracy: 0.5370, Validation Accuracy: 0.5462, Loss: 0.9139
# Epoch   0 Batch  140/538 - Train Accuracy: 0.5299, Validation Accuracy: 0.5737, Loss: 0.9660
# Epoch   0 Batch  150/538 - Train Accuracy: 0.5861, Validation Accuracy: 0.5868, Loss: 0.8586
# Epoch   0 Batch  160/538 - Train Accuracy: 0.5908, Validation Accuracy: 0.5913, Loss: 0.7861
# Epoch   0 Batch  170/538 - Train Accuracy: 0.6172, Validation Accuracy: 0.5991, Loss: 0.7534
# Epoch   0 Batch  180/538 - Train Accuracy: 0.6321, Validation Accuracy: 0.6072, Loss: 0.7351
# Epoch   0 Batch  190/538 - Train Accuracy: 0.5915, Validation Accuracy: 0.6044, Loss: 0.7359
# Epoch   0 Batch  200/538 - Train Accuracy: 0.6082, Validation Accuracy: 0.6112, Loss: 0.7021
# Epoch   0 Batch  210/538 - Train Accuracy: 0.6025, Validation Accuracy: 0.6096, Loss: 0.6653
# Epoch   0 Batch  220/538 - Train Accuracy: 0.5837, Validation Accuracy: 0.6220, Loss: 0.6279
# Epoch   0 Batch  230/538 - Train Accuracy: 0.6123, Validation Accuracy: 0.6115, Loss: 0.6453
# Epoch   0 Batch  240/538 - Train Accuracy: 0.5992, Validation Accuracy: 0.6326, Loss: 0.6373
# Epoch   0 Batch  250/538 - Train Accuracy: 0.6209, Validation Accuracy: 0.6186, Loss: 0.5846
# Epoch   0 Batch  260/538 - Train Accuracy: 0.6083, Validation Accuracy: 0.6408, Loss: 0.5748
# Epoch   0 Batch  270/538 - Train Accuracy: 0.6064, Validation Accuracy: 0.6422, Loss: 0.5831
# Epoch   0 Batch  280/538 - Train Accuracy: 0.6669, Validation Accuracy: 0.6467, Loss: 0.5282
# Epoch   0 Batch  290/538 - Train Accuracy: 0.6492, Validation Accuracy: 0.6634, Loss: 0.5305
# Epoch   0 Batch  300/538 - Train Accuracy: 0.6700, Validation Accuracy: 0.6857, Loss: 0.5036
# Epoch   0 Batch  310/538 - Train Accuracy: 0.6959, Validation Accuracy: 0.6857, Loss: 0.4988
# Epoch   0 Batch  320/538 - Train Accuracy: 0.6951, Validation Accuracy: 0.6964, Loss: 0.4662
# Epoch   0 Batch  330/538 - Train Accuracy: 0.7413, Validation Accuracy: 0.7051, Loss: 0.4305
# Epoch   0 Batch  340/538 - Train Accuracy: 0.7238, Validation Accuracy: 0.7246, Loss: 0.4414
# Epoch   0 Batch  350/538 - Train Accuracy: 0.7160, Validation Accuracy: 0.7164, Loss: 0.4242
# Epoch   0 Batch  360/538 - Train Accuracy: 0.7334, Validation Accuracy: 0.7399, Loss: 0.4074
# Epoch   0 Batch  370/538 - Train Accuracy: 0.7449, Validation Accuracy: 0.7624, Loss: 0.3838
# Epoch   0 Batch  380/538 - Train Accuracy: 0.7889, Validation Accuracy: 0.7699, Loss: 0.3432
# Epoch   0 Batch  390/538 - Train Accuracy: 0.8062, Validation Accuracy: 0.7775, Loss: 0.3227
# Epoch   0 Batch  400/538 - Train Accuracy: 0.8105, Validation Accuracy: 0.7695, Loss: 0.3205
# Epoch   0 Batch  410/538 - Train Accuracy: 0.8219, Validation Accuracy: 0.8065, Loss: 0.3172
# Epoch   0 Batch  420/538 - Train Accuracy: 0.8391, Validation Accuracy: 0.8217, Loss: 0.2706
# Epoch   0 Batch  430/538 - Train Accuracy: 0.8363, Validation Accuracy: 0.8271, Loss: 0.2491
# Epoch   0 Batch  440/538 - Train Accuracy: 0.8385, Validation Accuracy: 0.8244, Loss: 0.2617
# Epoch   0 Batch  450/538 - Train Accuracy: 0.8465, Validation Accuracy: 0.8567, Loss: 0.2415
# Epoch   0 Batch  460/538 - Train Accuracy: 0.8495, Validation Accuracy: 0.8702, Loss: 0.2164
# Epoch   0 Batch  470/538 - Train Accuracy: 0.8648, Validation Accuracy: 0.8297, Loss: 0.1844
# Epoch   0 Batch  480/538 - Train Accuracy: 0.8865, Validation Accuracy: 0.8551, Loss: 0.1770
# Epoch   0 Batch  490/538 - Train Accuracy: 0.8832, Validation Accuracy: 0.8766, Loss: 0.1586
# Epoch   0 Batch  500/538 - Train Accuracy: 0.9016, Validation Accuracy: 0.8652, Loss: 0.1381
# Epoch   0 Batch  510/538 - Train Accuracy: 0.8973, Validation Accuracy: 0.8956, Loss: 0.1411
# Epoch   0 Batch  520/538 - Train Accuracy: 0.8875, Validation Accuracy: 0.8635, Loss: 0.1465
# Epoch   0 Batch  530/538 - Train Accuracy: 0.8889, Validation Accuracy: 0.8837, Loss: 0.1447
# Epoch   1 Batch   10/538 - Train Accuracy: 0.9010, Validation Accuracy: 0.8839, Loss: 0.1229
# Epoch   1 Batch   20/538 - Train Accuracy: 0.9018, Validation Accuracy: 0.9059, Loss: 0.1166
# Epoch   1 Batch   30/538 - Train Accuracy: 0.8916, Validation Accuracy: 0.9050, Loss: 0.1196
# Epoch   1 Batch   40/538 - Train Accuracy: 0.9146, Validation Accuracy: 0.9146, Loss: 0.0914
# Epoch   1 Batch   50/538 - Train Accuracy: 0.9139, Validation Accuracy: 0.8880, Loss: 0.0995
# Epoch   1 Batch   60/538 - Train Accuracy: 0.9225, Validation Accuracy: 0.8968, Loss: 0.0959
# Epoch   1 Batch   70/538 - Train Accuracy: 0.8990, Validation Accuracy: 0.9210, Loss: 0.0923
# Epoch   1 Batch   80/538 - Train Accuracy: 0.9123, Validation Accuracy: 0.9052, Loss: 0.0982
# Epoch   1 Batch   90/538 - Train Accuracy: 0.9076, Validation Accuracy: 0.8810, Loss: 0.0959
# Epoch   1 Batch  100/538 - Train Accuracy: 0.9244, Validation Accuracy: 0.9100, Loss: 0.0774
# Epoch   1 Batch  110/538 - Train Accuracy: 0.9168, Validation Accuracy: 0.9224, Loss: 0.0853
# Epoch   1 Batch  120/538 - Train Accuracy: 0.9365, Validation Accuracy: 0.9274, Loss: 0.0692
# Epoch   1 Batch  130/538 - Train Accuracy: 0.9278, Validation Accuracy: 0.9015, Loss: 0.0680
# Epoch   1 Batch  140/538 - Train Accuracy: 0.9174, Validation Accuracy: 0.9130, Loss: 0.0965
# Epoch   1 Batch  150/538 - Train Accuracy: 0.9213, Validation Accuracy: 0.9105, Loss: 0.0693
# Epoch   1 Batch  160/538 - Train Accuracy: 0.9085, Validation Accuracy: 0.9229, Loss: 0.0657
# Epoch   1 Batch  170/538 - Train Accuracy: 0.9085, Validation Accuracy: 0.9146, Loss: 0.0766
# Epoch   1 Batch  180/538 - Train Accuracy: 0.9250, Validation Accuracy: 0.9212, Loss: 0.0737
# Epoch   1 Batch  190/538 - Train Accuracy: 0.9161, Validation Accuracy: 0.9194, Loss: 0.0914
# Epoch   1 Batch  200/538 - Train Accuracy: 0.9457, Validation Accuracy: 0.9181, Loss: 0.0563
# Epoch   1 Batch  210/538 - Train Accuracy: 0.9247, Validation Accuracy: 0.9203, Loss: 0.0704
# Epoch   1 Batch  220/538 - Train Accuracy: 0.9102, Validation Accuracy: 0.9316, Loss: 0.0638
# Epoch   1 Batch  230/538 - Train Accuracy: 0.9395, Validation Accuracy: 0.9332, Loss: 0.0592
# Epoch   1 Batch  240/538 - Train Accuracy: 0.9332, Validation Accuracy: 0.9304, Loss: 0.0631
# Epoch   1 Batch  250/538 - Train Accuracy: 0.9557, Validation Accuracy: 0.9267, Loss: 0.0602
# Epoch   1 Batch  260/538 - Train Accuracy: 0.9018, Validation Accuracy: 0.9279, Loss: 0.0658
# Epoch   1 Batch  270/538 - Train Accuracy: 0.9334, Validation Accuracy: 0.9318, Loss: 0.0529
# Epoch   1 Batch  280/538 - Train Accuracy: 0.9453, Validation Accuracy: 0.9176, Loss: 0.0572
# Epoch   1 Batch  290/538 - Train Accuracy: 0.9525, Validation Accuracy: 0.9320, Loss: 0.0515
# Epoch   1 Batch  300/538 - Train Accuracy: 0.9299, Validation Accuracy: 0.9395, Loss: 0.0582
# Epoch   1 Batch  310/538 - Train Accuracy: 0.9510, Validation Accuracy: 0.9425, Loss: 0.0636
# Epoch   1 Batch  320/538 - Train Accuracy: 0.9457, Validation Accuracy: 0.9462, Loss: 0.0486
# Epoch   1 Batch  330/538 - Train Accuracy: 0.9643, Validation Accuracy: 0.9235, Loss: 0.0511
# Epoch   1 Batch  340/538 - Train Accuracy: 0.9395, Validation Accuracy: 0.9430, Loss: 0.0547
# Epoch   1 Batch  350/538 - Train Accuracy: 0.9382, Validation Accuracy: 0.9411, Loss: 0.0563
# Epoch   1 Batch  360/538 - Train Accuracy: 0.9412, Validation Accuracy: 0.9462, Loss: 0.0548
# Epoch   1 Batch  370/538 - Train Accuracy: 0.9520, Validation Accuracy: 0.9506, Loss: 0.0468
# Epoch   1 Batch  380/538 - Train Accuracy: 0.9391, Validation Accuracy: 0.9466, Loss: 0.0436
# Epoch   1 Batch  390/538 - Train Accuracy: 0.9622, Validation Accuracy: 0.9515, Loss: 0.0407
# Epoch   1 Batch  400/538 - Train Accuracy: 0.9353, Validation Accuracy: 0.9324, Loss: 0.0479
# Epoch   1 Batch  410/538 - Train Accuracy: 0.9625, Validation Accuracy: 0.9462, Loss: 0.0482
# Epoch   1 Batch  420/538 - Train Accuracy: 0.9654, Validation Accuracy: 0.9446, Loss: 0.0442
# Epoch   1 Batch  430/538 - Train Accuracy: 0.9373, Validation Accuracy: 0.9304, Loss: 0.0411
# Epoch   1 Batch  440/538 - Train Accuracy: 0.9459, Validation Accuracy: 0.9531, Loss: 0.0552
# Epoch   1 Batch  450/538 - Train Accuracy: 0.9258, Validation Accuracy: 0.9466, Loss: 0.0622
# Epoch   1 Batch  460/538 - Train Accuracy: 0.9291, Validation Accuracy: 0.9482, Loss: 0.0482
# Epoch   1 Batch  470/538 - Train Accuracy: 0.9522, Validation Accuracy: 0.9338, Loss: 0.0433
# Epoch   1 Batch  480/538 - Train Accuracy: 0.9557, Validation Accuracy: 0.9396, Loss: 0.0433
# Epoch   1 Batch  490/538 - Train Accuracy: 0.9501, Validation Accuracy: 0.9364, Loss: 0.0427
# Epoch   1 Batch  500/538 - Train Accuracy: 0.9627, Validation Accuracy: 0.9409, Loss: 0.0331
# Epoch   1 Batch  510/538 - Train Accuracy: 0.9639, Validation Accuracy: 0.9482, Loss: 0.0373
# Epoch   1 Batch  520/538 - Train Accuracy: 0.9496, Validation Accuracy: 0.9537, Loss: 0.0427
# Epoch   1 Batch  530/538 - Train Accuracy: 0.9441, Validation Accuracy: 0.9513, Loss: 0.0433
# Epoch   2 Batch   10/538 - Train Accuracy: 0.9432, Validation Accuracy: 0.9458, Loss: 0.0442
# Epoch   2 Batch   20/538 - Train Accuracy: 0.9572, Validation Accuracy: 0.9521, Loss: 0.0431
# Epoch   2 Batch   30/538 - Train Accuracy: 0.9424, Validation Accuracy: 0.9654, Loss: 0.0446
# Epoch   2 Batch   40/538 - Train Accuracy: 0.9471, Validation Accuracy: 0.9647, Loss: 0.0304
# Epoch   2 Batch   50/538 - Train Accuracy: 0.9518, Validation Accuracy: 0.9551, Loss: 0.0373
# Epoch   2 Batch   60/538 - Train Accuracy: 0.9506, Validation Accuracy: 0.9533, Loss: 0.0382
# Epoch   2 Batch   70/538 - Train Accuracy: 0.9288, Validation Accuracy: 0.9473, Loss: 0.0351
# Epoch   2 Batch   80/538 - Train Accuracy: 0.9445, Validation Accuracy: 0.9600, Loss: 0.0439
# Epoch   2 Batch   90/538 - Train Accuracy: 0.9572, Validation Accuracy: 0.9638, Loss: 0.0443
# Epoch   2 Batch  100/538 - Train Accuracy: 0.9641, Validation Accuracy: 0.9640, Loss: 0.0297
# Epoch   2 Batch  110/538 - Train Accuracy: 0.9619, Validation Accuracy: 0.9608, Loss: 0.0331
# Epoch   2 Batch  120/538 - Train Accuracy: 0.9664, Validation Accuracy: 0.9581, Loss: 0.0266
# Epoch   2 Batch  130/538 - Train Accuracy: 0.9515, Validation Accuracy: 0.9556, Loss: 0.0349
# Epoch   2 Batch  140/538 - Train Accuracy: 0.9520, Validation Accuracy: 0.9629, Loss: 0.0486
# Epoch   2 Batch  150/538 - Train Accuracy: 0.9678, Validation Accuracy: 0.9558, Loss: 0.0305
# Epoch   2 Batch  160/538 - Train Accuracy: 0.9410, Validation Accuracy: 0.9453, Loss: 0.0285
# Epoch   2 Batch  170/538 - Train Accuracy: 0.9701, Validation Accuracy: 0.9537, Loss: 0.0318
# Epoch   2 Batch  180/538 - Train Accuracy: 0.9446, Validation Accuracy: 0.9592, Loss: 0.0367
# Epoch   2 Batch  190/538 - Train Accuracy: 0.9539, Validation Accuracy: 0.9549, Loss: 0.0460
# Epoch   2 Batch  200/538 - Train Accuracy: 0.9656, Validation Accuracy: 0.9538, Loss: 0.0261
# Epoch   2 Batch  210/538 - Train Accuracy: 0.9524, Validation Accuracy: 0.9540, Loss: 0.0364
# Epoch   2 Batch  220/538 - Train Accuracy: 0.9617, Validation Accuracy: 0.9540, Loss: 0.0380
# Epoch   2 Batch  230/538 - Train Accuracy: 0.9754, Validation Accuracy: 0.9528, Loss: 0.0293
# Epoch   2 Batch  240/538 - Train Accuracy: 0.9637, Validation Accuracy: 0.9624, Loss: 0.0344
# Epoch   2 Batch  250/538 - Train Accuracy: 0.9564, Validation Accuracy: 0.9597, Loss: 0.0318
# Epoch   2 Batch  260/538 - Train Accuracy: 0.9494, Validation Accuracy: 0.9469, Loss: 0.0354
# Epoch   2 Batch  270/538 - Train Accuracy: 0.9594, Validation Accuracy: 0.9563, Loss: 0.0278
# Epoch   2 Batch  280/538 - Train Accuracy: 0.9751, Validation Accuracy: 0.9664, Loss: 0.0268
# Epoch   2 Batch  290/538 - Train Accuracy: 0.9648, Validation Accuracy: 0.9524, Loss: 0.0246
# Epoch   2 Batch  300/538 - Train Accuracy: 0.9507, Validation Accuracy: 0.9625, Loss: 0.0305
# Epoch   2 Batch  310/538 - Train Accuracy: 0.9707, Validation Accuracy: 0.9680, Loss: 0.0360
# Epoch   2 Batch  320/538 - Train Accuracy: 0.9615, Validation Accuracy: 0.9666, Loss: 0.0280
# Epoch   2 Batch  330/538 - Train Accuracy: 0.9741, Validation Accuracy: 0.9672, Loss: 0.0270
# Epoch   2 Batch  340/538 - Train Accuracy: 0.9613, Validation Accuracy: 0.9577, Loss: 0.0314
# Epoch   2 Batch  350/538 - Train Accuracy: 0.9699, Validation Accuracy: 0.9611, Loss: 0.0313
# Epoch   2 Batch  360/538 - Train Accuracy: 0.9678, Validation Accuracy: 0.9648, Loss: 0.0260
# Epoch   2 Batch  370/538 - Train Accuracy: 0.9625, Validation Accuracy: 0.9556, Loss: 0.0262
# Epoch   2 Batch  380/538 - Train Accuracy: 0.9623, Validation Accuracy: 0.9632, Loss: 0.0255
# Epoch   2 Batch  390/538 - Train Accuracy: 0.9686, Validation Accuracy: 0.9537, Loss: 0.0222
# Epoch   2 Batch  400/538 - Train Accuracy: 0.9749, Validation Accuracy: 0.9540, Loss: 0.0264
# Epoch   2 Batch  410/538 - Train Accuracy: 0.9828, Validation Accuracy: 0.9567, Loss: 0.0291
# Epoch   2 Batch  420/538 - Train Accuracy: 0.9721, Validation Accuracy: 0.9616, Loss: 0.0275
# Epoch   2 Batch  430/538 - Train Accuracy: 0.9639, Validation Accuracy: 0.9634, Loss: 0.0279
# Epoch   2 Batch  440/538 - Train Accuracy: 0.9797, Validation Accuracy: 0.9608, Loss: 0.0301
# Epoch   2 Batch  450/538 - Train Accuracy: 0.9449, Validation Accuracy: 0.9686, Loss: 0.0364
# Epoch   2 Batch  460/538 - Train Accuracy: 0.9609, Validation Accuracy: 0.9622, Loss: 0.0285
# Epoch   2 Batch  470/538 - Train Accuracy: 0.9652, Validation Accuracy: 0.9561, Loss: 0.0270
# Epoch   2 Batch  480/538 - Train Accuracy: 0.9829, Validation Accuracy: 0.9608, Loss: 0.0242
# Epoch   2 Batch  490/538 - Train Accuracy: 0.9645, Validation Accuracy: 0.9631, Loss: 0.0291
# Epoch   2 Batch  500/538 - Train Accuracy: 0.9735, Validation Accuracy: 0.9673, Loss: 0.0199
# Epoch   2 Batch  510/538 - Train Accuracy: 0.9715, Validation Accuracy: 0.9661, Loss: 0.0242
# Epoch   2 Batch  520/538 - Train Accuracy: 0.9779, Validation Accuracy: 0.9615, Loss: 0.0240
# Epoch   2 Batch  530/538 - Train Accuracy: 0.9768, Validation Accuracy: 0.9654, Loss: 0.0293
# Epoch   3 Batch   10/538 - Train Accuracy: 0.9639, Validation Accuracy: 0.9735, Loss: 0.0282
# Epoch   3 Batch   20/538 - Train Accuracy: 0.9753, Validation Accuracy: 0.9728, Loss: 0.0264
# Epoch   3 Batch   30/538 - Train Accuracy: 0.9689, Validation Accuracy: 0.9579, Loss: 0.0269
# Epoch   3 Batch   40/538 - Train Accuracy: 0.9652, Validation Accuracy: 0.9647, Loss: 0.0185
# Epoch   3 Batch   50/538 - Train Accuracy: 0.9725, Validation Accuracy: 0.9583, Loss: 0.0213
# Epoch   3 Batch   60/538 - Train Accuracy: 0.9693, Validation Accuracy: 0.9696, Loss: 0.0281
# Epoch   3 Batch   70/538 - Train Accuracy: 0.9697, Validation Accuracy: 0.9689, Loss: 0.0203
# Epoch   3 Batch   80/538 - Train Accuracy: 0.9684, Validation Accuracy: 0.9689, Loss: 0.0238
# Epoch   3 Batch   90/538 - Train Accuracy: 0.9706, Validation Accuracy: 0.9739, Loss: 0.0231
# Epoch   3 Batch  100/538 - Train Accuracy: 0.9721, Validation Accuracy: 0.9709, Loss: 0.0189
# Epoch   3 Batch  110/538 - Train Accuracy: 0.9777, Validation Accuracy: 0.9618, Loss: 0.0216
# Epoch   3 Batch  120/538 - Train Accuracy: 0.9764, Validation Accuracy: 0.9652, Loss: 0.0193
# Epoch   3 Batch  130/538 - Train Accuracy: 0.9628, Validation Accuracy: 0.9640, Loss: 0.0244
# Epoch   3 Batch  140/538 - Train Accuracy: 0.9658, Validation Accuracy: 0.9611, Loss: 0.0352
# Epoch   3 Batch  150/538 - Train Accuracy: 0.9820, Validation Accuracy: 0.9581, Loss: 0.0226
# Epoch   3 Batch  160/538 - Train Accuracy: 0.9734, Validation Accuracy: 0.9597, Loss: 0.0191
# Epoch   3 Batch  170/538 - Train Accuracy: 0.9693, Validation Accuracy: 0.9632, Loss: 0.0273
# Epoch   3 Batch  180/538 - Train Accuracy: 0.9632, Validation Accuracy: 0.9629, Loss: 0.0211
# Epoch   3 Batch  190/538 - Train Accuracy: 0.9661, Validation Accuracy: 0.9556, Loss: 0.0305
# Epoch   3 Batch  200/538 - Train Accuracy: 0.9777, Validation Accuracy: 0.9521, Loss: 0.0193
# Epoch   3 Batch  210/538 - Train Accuracy: 0.9667, Validation Accuracy: 0.9577, Loss: 0.0262
# Epoch   3 Batch  220/538 - Train Accuracy: 0.9574, Validation Accuracy: 0.9593, Loss: 0.0270
# Epoch   3 Batch  230/538 - Train Accuracy: 0.9756, Validation Accuracy: 0.9567, Loss: 0.0203
# Epoch   3 Batch  240/538 - Train Accuracy: 0.9568, Validation Accuracy: 0.9597, Loss: 0.0251
# Epoch   3 Batch  250/538 - Train Accuracy: 0.9748, Validation Accuracy: 0.9592, Loss: 0.0273
# Epoch   3 Batch  260/538 - Train Accuracy: 0.9596, Validation Accuracy: 0.9551, Loss: 0.0259
# Epoch   3 Batch  270/538 - Train Accuracy: 0.9816, Validation Accuracy: 0.9597, Loss: 0.0184
# Epoch   3 Batch  280/538 - Train Accuracy: 0.9741, Validation Accuracy: 0.9659, Loss: 0.0170
# Epoch   3 Batch  290/538 - Train Accuracy: 0.9832, Validation Accuracy: 0.9719, Loss: 0.0184
# Epoch   3 Batch  300/538 - Train Accuracy: 0.9740, Validation Accuracy: 0.9659, Loss: 0.0224
# Epoch   3 Batch  310/538 - Train Accuracy: 0.9834, Validation Accuracy: 0.9691, Loss: 0.0246
# Epoch   3 Batch  320/538 - Train Accuracy: 0.9773, Validation Accuracy: 0.9522, Loss: 0.0191
# Epoch   3 Batch  330/538 - Train Accuracy: 0.9779, Validation Accuracy: 0.9702, Loss: 0.0202
# Epoch   3 Batch  340/538 - Train Accuracy: 0.9852, Validation Accuracy: 0.9576, Loss: 0.0186
# Epoch   3 Batch  350/538 - Train Accuracy: 0.9650, Validation Accuracy: 0.9638, Loss: 0.0211
# Epoch   3 Batch  360/538 - Train Accuracy: 0.9746, Validation Accuracy: 0.9668, Loss: 0.0194
# Epoch   3 Batch  370/538 - Train Accuracy: 0.9730, Validation Accuracy: 0.9703, Loss: 0.0232
# Epoch   3 Batch  380/538 - Train Accuracy: 0.9691, Validation Accuracy: 0.9609, Loss: 0.0207
# Epoch   3 Batch  390/538 - Train Accuracy: 0.9786, Validation Accuracy: 0.9510, Loss: 0.0169
# Epoch   3 Batch  400/538 - Train Accuracy: 0.9788, Validation Accuracy: 0.9734, Loss: 0.0203
# Epoch   3 Batch  410/538 - Train Accuracy: 0.9754, Validation Accuracy: 0.9700, Loss: 0.0191
# Epoch   3 Batch  420/538 - Train Accuracy: 0.9762, Validation Accuracy: 0.9766, Loss: 0.0216
# Epoch   3 Batch  430/538 - Train Accuracy: 0.9691, Validation Accuracy: 0.9712, Loss: 0.0183
# Epoch   3 Batch  440/538 - Train Accuracy: 0.9846, Validation Accuracy: 0.9647, Loss: 0.0203
# Epoch   3 Batch  450/538 - Train Accuracy: 0.9507, Validation Accuracy: 0.9661, Loss: 0.0259
# Epoch   3 Batch  460/538 - Train Accuracy: 0.9753, Validation Accuracy: 0.9739, Loss: 0.0229
# Epoch   3 Batch  470/538 - Train Accuracy: 0.9758, Validation Accuracy: 0.9677, Loss: 0.0236
# Epoch   3 Batch  480/538 - Train Accuracy: 0.9764, Validation Accuracy: 0.9581, Loss: 0.0202
# Epoch   3 Batch  490/538 - Train Accuracy: 0.9635, Validation Accuracy: 0.9554, Loss: 0.0219
# Epoch   3 Batch  500/538 - Train Accuracy: 0.9833, Validation Accuracy: 0.9574, Loss: 0.0145
# Epoch   3 Batch  510/538 - Train Accuracy: 0.9784, Validation Accuracy: 0.9691, Loss: 0.0153
# Epoch   3 Batch  520/538 - Train Accuracy: 0.9807, Validation Accuracy: 0.9696, Loss: 0.0226
# Epoch   3 Batch  530/538 - Train Accuracy: 0.9711, Validation Accuracy: 0.9634, Loss: 0.0188
# Epoch   4 Batch   10/538 - Train Accuracy: 0.9695, Validation Accuracy: 0.9661, Loss: 0.0182
# Epoch   4 Batch   20/538 - Train Accuracy: 0.9808, Validation Accuracy: 0.9684, Loss: 0.0231
# Epoch   4 Batch   30/538 - Train Accuracy: 0.9711, Validation Accuracy: 0.9691, Loss: 0.0209
# Epoch   4 Batch   40/538 - Train Accuracy: 0.9727, Validation Accuracy: 0.9721, Loss: 0.0163
# Epoch   4 Batch   50/538 - Train Accuracy: 0.9719, Validation Accuracy: 0.9652, Loss: 0.0171
# Epoch   4 Batch   60/538 - Train Accuracy: 0.9688, Validation Accuracy: 0.9670, Loss: 0.0236
# Epoch   4 Batch   70/538 - Train Accuracy: 0.9808, Validation Accuracy: 0.9730, Loss: 0.0151
# Epoch   4 Batch   80/538 - Train Accuracy: 0.9725, Validation Accuracy: 0.9684, Loss: 0.0166
# Epoch   4 Batch   90/538 - Train Accuracy: 0.9795, Validation Accuracy: 0.9688, Loss: 0.0207
# Epoch   4 Batch  100/538 - Train Accuracy: 0.9773, Validation Accuracy: 0.9691, Loss: 0.0139
# Epoch   4 Batch  110/538 - Train Accuracy: 0.9744, Validation Accuracy: 0.9638, Loss: 0.0177
# Epoch   4 Batch  120/538 - Train Accuracy: 0.9863, Validation Accuracy: 0.9735, Loss: 0.0162
# Epoch   4 Batch  130/538 - Train Accuracy: 0.9820, Validation Accuracy: 0.9741, Loss: 0.0180
# Epoch   4 Batch  140/538 - Train Accuracy: 0.9771, Validation Accuracy: 0.9654, Loss: 0.0225
# Epoch   4 Batch  150/538 - Train Accuracy: 0.9812, Validation Accuracy: 0.9652, Loss: 0.0167
# Epoch   4 Batch  160/538 - Train Accuracy: 0.9827, Validation Accuracy: 0.9661, Loss: 0.0179
# Epoch   4 Batch  170/538 - Train Accuracy: 0.9701, Validation Accuracy: 0.9711, Loss: 0.0180
# Epoch   4 Batch  180/538 - Train Accuracy: 0.9725, Validation Accuracy: 0.9611, Loss: 0.0163
# Epoch   4 Batch  190/538 - Train Accuracy: 0.9795, Validation Accuracy: 0.9760, Loss: 0.0219
# Epoch   4 Batch  200/538 - Train Accuracy: 0.9807, Validation Accuracy: 0.9743, Loss: 0.0129
# Epoch   4 Batch  210/538 - Train Accuracy: 0.9807, Validation Accuracy: 0.9766, Loss: 0.0183
# Epoch   4 Batch  220/538 - Train Accuracy: 0.9779, Validation Accuracy: 0.9641, Loss: 0.0187
# Epoch   4 Batch  230/538 - Train Accuracy: 0.9877, Validation Accuracy: 0.9691, Loss: 0.0147
# Epoch   4 Batch  240/538 - Train Accuracy: 0.9594, Validation Accuracy: 0.9739, Loss: 0.0188
# Epoch   4 Batch  250/538 - Train Accuracy: 0.9865, Validation Accuracy: 0.9703, Loss: 0.0168
# Epoch   4 Batch  260/538 - Train Accuracy: 0.9723, Validation Accuracy: 0.9679, Loss: 0.0210
# Epoch   4 Batch  270/538 - Train Accuracy: 0.9873, Validation Accuracy: 0.9656, Loss: 0.0137
# Epoch   4 Batch  280/538 - Train Accuracy: 0.9823, Validation Accuracy: 0.9741, Loss: 0.0127
# Epoch   4 Batch  290/538 - Train Accuracy: 0.9807, Validation Accuracy: 0.9677, Loss: 0.0142
# Epoch   4 Batch  300/538 - Train Accuracy: 0.9715, Validation Accuracy: 0.9757, Loss: 0.0159
# Epoch   4 Batch  310/538 - Train Accuracy: 0.9764, Validation Accuracy: 0.9686, Loss: 0.0192
# Epoch   4 Batch  320/538 - Train Accuracy: 0.9741, Validation Accuracy: 0.9672, Loss: 0.0157
# Epoch   4 Batch  330/538 - Train Accuracy: 0.9825, Validation Accuracy: 0.9778, Loss: 0.0143
# Epoch   4 Batch  340/538 - Train Accuracy: 0.9824, Validation Accuracy: 0.9661, Loss: 0.0164
# Epoch   4 Batch  350/538 - Train Accuracy: 0.9758, Validation Accuracy: 0.9659, Loss: 0.0195
# Epoch   4 Batch  360/538 - Train Accuracy: 0.9773, Validation Accuracy: 0.9700, Loss: 0.0137
# Epoch   4 Batch  370/538 - Train Accuracy: 0.9738, Validation Accuracy: 0.9664, Loss: 0.0168
# Epoch   4 Batch  380/538 - Train Accuracy: 0.9824, Validation Accuracy: 0.9600, Loss: 0.0161
# Epoch   4 Batch  390/538 - Train Accuracy: 0.9714, Validation Accuracy: 0.9640, Loss: 0.0132
# Epoch   4 Batch  400/538 - Train Accuracy: 0.9844, Validation Accuracy: 0.9668, Loss: 0.0177
# Epoch   4 Batch  410/538 - Train Accuracy: 0.9938, Validation Accuracy: 0.9721, Loss: 0.0146
# Epoch   4 Batch  420/538 - Train Accuracy: 0.9846, Validation Accuracy: 0.9737, Loss: 0.0168
# Epoch   4 Batch  430/538 - Train Accuracy: 0.9836, Validation Accuracy: 0.9709, Loss: 0.0132
# Epoch   4 Batch  440/538 - Train Accuracy: 0.9916, Validation Accuracy: 0.9686, Loss: 0.0152
# Epoch   4 Batch  450/538 - Train Accuracy: 0.9615, Validation Accuracy: 0.9727, Loss: 0.0222
# Epoch   4 Batch  460/538 - Train Accuracy: 0.9745, Validation Accuracy: 0.9721, Loss: 0.0185
# Epoch   4 Batch  470/538 - Train Accuracy: 0.9775, Validation Accuracy: 0.9686, Loss: 0.0174
# Epoch   4 Batch  480/538 - Train Accuracy: 0.9874, Validation Accuracy: 0.9585, Loss: 0.0160
# Epoch   4 Batch  490/538 - Train Accuracy: 0.9769, Validation Accuracy: 0.9673, Loss: 0.0160
# Epoch   4 Batch  500/538 - Train Accuracy: 0.9957, Validation Accuracy: 0.9753, Loss: 0.0088
# Epoch   4 Batch  510/538 - Train Accuracy: 0.9870, Validation Accuracy: 0.9746, Loss: 0.0118
# Epoch   4 Batch  520/538 - Train Accuracy: 0.9811, Validation Accuracy: 0.9666, Loss: 0.0179
# Epoch   4 Batch  530/538 - Train Accuracy: 0.9738, Validation Accuracy: 0.9709, Loss: 0.0178
# Epoch   5 Batch   10/538 - Train Accuracy: 0.9803, Validation Accuracy: 0.9776, Loss: 0.0130
# Epoch   5 Batch   20/538 - Train Accuracy: 0.9831, Validation Accuracy: 0.9780, Loss: 0.0160
# Epoch   5 Batch   30/538 - Train Accuracy: 0.9719, Validation Accuracy: 0.9741, Loss: 0.0156
# Epoch   5 Batch   40/538 - Train Accuracy: 0.9831, Validation Accuracy: 0.9682, Loss: 0.0132
# Epoch   5 Batch   50/538 - Train Accuracy: 0.9787, Validation Accuracy: 0.9769, Loss: 0.0126
# Epoch   5 Batch   60/538 - Train Accuracy: 0.9754, Validation Accuracy: 0.9806, Loss: 0.0186
# Epoch   5 Batch   70/538 - Train Accuracy: 0.9818, Validation Accuracy: 0.9808, Loss: 0.0121
# Epoch   5 Batch   80/538 - Train Accuracy: 0.9908, Validation Accuracy: 0.9698, Loss: 0.0127
# Epoch   5 Batch   90/538 - Train Accuracy: 0.9728, Validation Accuracy: 0.9686, Loss: 0.0202
# Epoch   5 Batch  100/538 - Train Accuracy: 0.9854, Validation Accuracy: 0.9750, Loss: 0.0122
# Epoch   5 Batch  110/538 - Train Accuracy: 0.9867, Validation Accuracy: 0.9643, Loss: 0.0119
# Epoch   5 Batch  120/538 - Train Accuracy: 0.9900, Validation Accuracy: 0.9734, Loss: 0.0118
# Epoch   5 Batch  130/538 - Train Accuracy: 0.9797, Validation Accuracy: 0.9790, Loss: 0.0149
# Epoch   5 Batch  140/538 - Train Accuracy: 0.9906, Validation Accuracy: 0.9755, Loss: 0.0147
# Epoch   5 Batch  150/538 - Train Accuracy: 0.9867, Validation Accuracy: 0.9744, Loss: 0.0135
# Epoch   5 Batch  160/538 - Train Accuracy: 0.9814, Validation Accuracy: 0.9677, Loss: 0.0141
# Epoch   5 Batch  170/538 - Train Accuracy: 0.9790, Validation Accuracy: 0.9730, Loss: 0.0155
# Epoch   5 Batch  180/538 - Train Accuracy: 0.9764, Validation Accuracy: 0.9776, Loss: 0.0175
# Epoch   5 Batch  190/538 - Train Accuracy: 0.9814, Validation Accuracy: 0.9721, Loss: 0.0198
# Epoch   5 Batch  200/538 - Train Accuracy: 0.9781, Validation Accuracy: 0.9661, Loss: 0.0126
# Epoch   5 Batch  210/538 - Train Accuracy: 0.9890, Validation Accuracy: 0.9737, Loss: 0.0126
# Epoch   5 Batch  220/538 - Train Accuracy: 0.9859, Validation Accuracy: 0.9732, Loss: 0.0151
# Epoch   5 Batch  230/538 - Train Accuracy: 0.9844, Validation Accuracy: 0.9645, Loss: 0.0163
# Epoch   5 Batch  240/538 - Train Accuracy: 0.9686, Validation Accuracy: 0.9673, Loss: 0.0180
# Epoch   5 Batch  250/538 - Train Accuracy: 0.9881, Validation Accuracy: 0.9657, Loss: 0.0141
# Epoch   5 Batch  260/538 - Train Accuracy: 0.9663, Validation Accuracy: 0.9759, Loss: 0.0163
# Epoch   5 Batch  270/538 - Train Accuracy: 0.9877, Validation Accuracy: 0.9744, Loss: 0.0103
# Epoch   5 Batch  280/538 - Train Accuracy: 0.9896, Validation Accuracy: 0.9705, Loss: 0.0111
# Epoch   5 Batch  290/538 - Train Accuracy: 0.9855, Validation Accuracy: 0.9783, Loss: 0.0105
# Epoch   5 Batch  300/538 - Train Accuracy: 0.9950, Validation Accuracy: 0.9700, Loss: 0.0129
# Epoch   5 Batch  310/538 - Train Accuracy: 0.9762, Validation Accuracy: 0.9735, Loss: 0.0153
# Epoch   5 Batch  320/538 - Train Accuracy: 0.9847, Validation Accuracy: 0.9760, Loss: 0.0133
# Epoch   5 Batch  330/538 - Train Accuracy: 0.9853, Validation Accuracy: 0.9741, Loss: 0.0129
# Epoch   5 Batch  340/538 - Train Accuracy: 0.9854, Validation Accuracy: 0.9725, Loss: 0.0120
# Epoch   5 Batch  350/538 - Train Accuracy: 0.9821, Validation Accuracy: 0.9682, Loss: 0.0155
# Epoch   5 Batch  360/538 - Train Accuracy: 0.9793, Validation Accuracy: 0.9684, Loss: 0.0114
# Epoch   5 Batch  370/538 - Train Accuracy: 0.9855, Validation Accuracy: 0.9698, Loss: 0.0116
# Epoch   5 Batch  380/538 - Train Accuracy: 0.9889, Validation Accuracy: 0.9609, Loss: 0.0138
# Epoch   5 Batch  390/538 - Train Accuracy: 0.9898, Validation Accuracy: 0.9592, Loss: 0.0118
# Epoch   5 Batch  400/538 - Train Accuracy: 0.9834, Validation Accuracy: 0.9741, Loss: 0.0139
# Epoch   5 Batch  410/538 - Train Accuracy: 0.9883, Validation Accuracy: 0.9737, Loss: 0.0112
# Epoch   5 Batch  420/538 - Train Accuracy: 0.9840, Validation Accuracy: 0.9705, Loss: 0.0163
# Epoch   5 Batch  430/538 - Train Accuracy: 0.9840, Validation Accuracy: 0.9741, Loss: 0.0132
# Epoch   5 Batch  440/538 - Train Accuracy: 0.9902, Validation Accuracy: 0.9718, Loss: 0.0127
# Epoch   5 Batch  450/538 - Train Accuracy: 0.9656, Validation Accuracy: 0.9794, Loss: 0.0190
# Epoch   5 Batch  460/538 - Train Accuracy: 0.9851, Validation Accuracy: 0.9688, Loss: 0.0140
# Epoch   5 Batch  470/538 - Train Accuracy: 0.9846, Validation Accuracy: 0.9672, Loss: 0.0156
# Epoch   5 Batch  480/538 - Train Accuracy: 0.9888, Validation Accuracy: 0.9751, Loss: 0.0157
# Epoch   5 Batch  490/538 - Train Accuracy: 0.9820, Validation Accuracy: 0.9663, Loss: 0.0134
# Epoch   5 Batch  500/538 - Train Accuracy: 0.9824, Validation Accuracy: 0.9673, Loss: 0.0089
# Epoch   5 Batch  510/538 - Train Accuracy: 0.9836, Validation Accuracy: 0.9750, Loss: 0.0107
# Epoch   5 Batch  520/538 - Train Accuracy: 0.9752, Validation Accuracy: 0.9757, Loss: 0.0144
# Epoch   5 Batch  530/538 - Train Accuracy: 0.9873, Validation Accuracy: 0.9778, Loss: 0.0129
# Epoch   6 Batch   10/538 - Train Accuracy: 0.9814, Validation Accuracy: 0.9725, Loss: 0.0119
# Epoch   6 Batch   20/538 - Train Accuracy: 0.9885, Validation Accuracy: 0.9739, Loss: 0.0148
# Epoch   6 Batch   30/538 - Train Accuracy: 0.9758, Validation Accuracy: 0.9771, Loss: 0.0152
# Epoch   6 Batch   40/538 - Train Accuracy: 0.9833, Validation Accuracy: 0.9760, Loss: 0.0111
# Epoch   6 Batch   50/538 - Train Accuracy: 0.9816, Validation Accuracy: 0.9806, Loss: 0.0126
# Epoch   6 Batch   60/538 - Train Accuracy: 0.9807, Validation Accuracy: 0.9803, Loss: 0.0128
# Epoch   6 Batch   70/538 - Train Accuracy: 0.9820, Validation Accuracy: 0.9819, Loss: 0.0076
# Epoch   6 Batch   80/538 - Train Accuracy: 0.9895, Validation Accuracy: 0.9759, Loss: 0.0115
# Epoch   6 Batch   90/538 - Train Accuracy: 0.9881, Validation Accuracy: 0.9785, Loss: 0.0132
# Epoch   6 Batch  100/538 - Train Accuracy: 0.9881, Validation Accuracy: 0.9808, Loss: 0.0089
# Epoch   6 Batch  110/538 - Train Accuracy: 0.9816, Validation Accuracy: 0.9735, Loss: 0.0118
# Epoch   6 Batch  120/538 - Train Accuracy: 0.9908, Validation Accuracy: 0.9762, Loss: 0.0076
# Epoch   6 Batch  130/538 - Train Accuracy: 0.9831, Validation Accuracy: 0.9771, Loss: 0.0128
# Epoch   6 Batch  140/538 - Train Accuracy: 0.9877, Validation Accuracy: 0.9766, Loss: 0.0158
# Epoch   6 Batch  150/538 - Train Accuracy: 0.9871, Validation Accuracy: 0.9828, Loss: 0.0094
# Epoch   6 Batch  160/538 - Train Accuracy: 0.9803, Validation Accuracy: 0.9746, Loss: 0.0120
# Epoch   6 Batch  170/538 - Train Accuracy: 0.9788, Validation Accuracy: 0.9743, Loss: 0.0142
# Epoch   6 Batch  180/538 - Train Accuracy: 0.9797, Validation Accuracy: 0.9606, Loss: 0.0147
# Epoch   6 Batch  190/538 - Train Accuracy: 0.9829, Validation Accuracy: 0.9716, Loss: 0.0147
# Epoch   6 Batch  200/538 - Train Accuracy: 0.9902, Validation Accuracy: 0.9755, Loss: 0.0088
# Epoch   6 Batch  210/538 - Train Accuracy: 0.9881, Validation Accuracy: 0.9746, Loss: 0.0126
# Epoch   6 Batch  220/538 - Train Accuracy: 0.9834, Validation Accuracy: 0.9764, Loss: 0.0127
# Epoch   6 Batch  230/538 - Train Accuracy: 0.9809, Validation Accuracy: 0.9659, Loss: 0.0126
# Epoch   6 Batch  240/538 - Train Accuracy: 0.9734, Validation Accuracy: 0.9679, Loss: 0.0139
# Epoch   6 Batch  250/538 - Train Accuracy: 0.9859, Validation Accuracy: 0.9672, Loss: 0.0133
# Epoch   6 Batch  260/538 - Train Accuracy: 0.9736, Validation Accuracy: 0.9684, Loss: 0.0165
# Epoch   6 Batch  270/538 - Train Accuracy: 0.9938, Validation Accuracy: 0.9721, Loss: 0.0106
# Epoch   6 Batch  280/538 - Train Accuracy: 0.9874, Validation Accuracy: 0.9725, Loss: 0.0093
# Epoch   6 Batch  290/538 - Train Accuracy: 0.9854, Validation Accuracy: 0.9780, Loss: 0.0096
# Epoch   6 Batch  300/538 - Train Accuracy: 0.9903, Validation Accuracy: 0.9759, Loss: 0.0104
# Epoch   6 Batch  310/538 - Train Accuracy: 0.9883, Validation Accuracy: 0.9693, Loss: 0.0107
# Epoch   6 Batch  320/538 - Train Accuracy: 0.9918, Validation Accuracy: 0.9778, Loss: 0.0093
# Epoch   6 Batch  330/538 - Train Accuracy: 0.9905, Validation Accuracy: 0.9702, Loss: 0.0113
# Epoch   6 Batch  340/538 - Train Accuracy: 0.9846, Validation Accuracy: 0.9750, Loss: 0.0101
# Epoch   6 Batch  350/538 - Train Accuracy: 0.9881, Validation Accuracy: 0.9721, Loss: 0.0124
# Epoch   6 Batch  360/538 - Train Accuracy: 0.9859, Validation Accuracy: 0.9778, Loss: 0.0109
# Epoch   6 Batch  370/538 - Train Accuracy: 0.9889, Validation Accuracy: 0.9739, Loss: 0.0122
# Epoch   6 Batch  380/538 - Train Accuracy: 0.9846, Validation Accuracy: 0.9719, Loss: 0.0101
# Epoch   6 Batch  390/538 - Train Accuracy: 0.9821, Validation Accuracy: 0.9661, Loss: 0.0121
# Epoch   6 Batch  400/538 - Train Accuracy: 0.9846, Validation Accuracy: 0.9684, Loss: 0.0102
# Epoch   6 Batch  410/538 - Train Accuracy: 0.9980, Validation Accuracy: 0.9744, Loss: 0.0119
# Epoch   6 Batch  420/538 - Train Accuracy: 0.9809, Validation Accuracy: 0.9775, Loss: 0.0114
# Epoch   6 Batch  430/538 - Train Accuracy: 0.9879, Validation Accuracy: 0.9677, Loss: 0.0097
# Epoch   6 Batch  440/538 - Train Accuracy: 0.9879, Validation Accuracy: 0.9712, Loss: 0.0109
# Epoch   6 Batch  450/538 - Train Accuracy: 0.9823, Validation Accuracy: 0.9760, Loss: 0.0163
# Epoch   6 Batch  460/538 - Train Accuracy: 0.9784, Validation Accuracy: 0.9792, Loss: 0.0155
# Epoch   6 Batch  470/538 - Train Accuracy: 0.9855, Validation Accuracy: 0.9757, Loss: 0.0103
# Epoch   6 Batch  480/538 - Train Accuracy: 0.9887, Validation Accuracy: 0.9705, Loss: 0.0104
# Epoch   6 Batch  490/538 - Train Accuracy: 0.9805, Validation Accuracy: 0.9714, Loss: 0.0122
# Epoch   6 Batch  500/538 - Train Accuracy: 0.9940, Validation Accuracy: 0.9789, Loss: 0.0127
# Epoch   6 Batch  510/538 - Train Accuracy: 0.9846, Validation Accuracy: 0.9767, Loss: 0.0133
# Epoch   6 Batch  520/538 - Train Accuracy: 0.9854, Validation Accuracy: 0.9760, Loss: 0.0135
# Epoch   6 Batch  530/538 - Train Accuracy: 0.9809, Validation Accuracy: 0.9727, Loss: 0.0124
# Epoch   7 Batch   10/538 - Train Accuracy: 0.9924, Validation Accuracy: 0.9799, Loss: 0.0090
# Epoch   7 Batch   20/538 - Train Accuracy: 0.9875, Validation Accuracy: 0.9805, Loss: 0.0156
# Epoch   7 Batch   30/538 - Train Accuracy: 0.9811, Validation Accuracy: 0.9719, Loss: 0.0151
# Epoch   7 Batch   40/538 - Train Accuracy: 0.9888, Validation Accuracy: 0.9798, Loss: 0.0072
# Epoch   7 Batch   50/538 - Train Accuracy: 0.9807, Validation Accuracy: 0.9801, Loss: 0.0099
# Epoch   7 Batch   60/538 - Train Accuracy: 0.9814, Validation Accuracy: 0.9853, Loss: 0.0131
# Epoch   7 Batch   70/538 - Train Accuracy: 0.9751, Validation Accuracy: 0.9744, Loss: 0.0109
# Epoch   7 Batch   80/538 - Train Accuracy: 0.9867, Validation Accuracy: 0.9755, Loss: 0.0093
# Epoch   7 Batch   90/538 - Train Accuracy: 0.9844, Validation Accuracy: 0.9735, Loss: 0.0136
# Epoch   7 Batch  100/538 - Train Accuracy: 0.9850, Validation Accuracy: 0.9769, Loss: 0.0137
# Epoch   7 Batch  110/538 - Train Accuracy: 0.9848, Validation Accuracy: 0.9712, Loss: 0.0108
# Epoch   7 Batch  120/538 - Train Accuracy: 0.9875, Validation Accuracy: 0.9833, Loss: 0.0087
# Epoch   7 Batch  130/538 - Train Accuracy: 0.9844, Validation Accuracy: 0.9833, Loss: 0.0107
# Epoch   7 Batch  140/538 - Train Accuracy: 0.9873, Validation Accuracy: 0.9787, Loss: 0.0177
# Epoch   7 Batch  150/538 - Train Accuracy: 0.9859, Validation Accuracy: 0.9757, Loss: 0.0086
# Epoch   7 Batch  160/538 - Train Accuracy: 0.9797, Validation Accuracy: 0.9771, Loss: 0.0132
# Epoch   7 Batch  170/538 - Train Accuracy: 0.9905, Validation Accuracy: 0.9773, Loss: 0.0144
# Epoch   7 Batch  180/538 - Train Accuracy: 0.9864, Validation Accuracy: 0.9641, Loss: 0.0148
# Epoch   7 Batch  190/538 - Train Accuracy: 0.9769, Validation Accuracy: 0.9691, Loss: 0.0141
# Epoch   7 Batch  200/538 - Train Accuracy: 0.9885, Validation Accuracy: 0.9787, Loss: 0.0100
# Epoch   7 Batch  210/538 - Train Accuracy: 0.9935, Validation Accuracy: 0.9732, Loss: 0.0108
# Epoch   7 Batch  220/538 - Train Accuracy: 0.9851, Validation Accuracy: 0.9703, Loss: 0.0129
# Epoch   7 Batch  230/538 - Train Accuracy: 0.9883, Validation Accuracy: 0.9648, Loss: 0.0118
# Epoch   7 Batch  240/538 - Train Accuracy: 0.9773, Validation Accuracy: 0.9693, Loss: 0.0117
# Epoch   7 Batch  250/538 - Train Accuracy: 0.9951, Validation Accuracy: 0.9803, Loss: 0.0114
# Epoch   7 Batch  260/538 - Train Accuracy: 0.9766, Validation Accuracy: 0.9730, Loss: 0.0145
# Epoch   7 Batch  270/538 - Train Accuracy: 0.9906, Validation Accuracy: 0.9748, Loss: 0.0081
# Epoch   7 Batch  280/538 - Train Accuracy: 0.9879, Validation Accuracy: 0.9636, Loss: 0.0107
# Epoch   7 Batch  290/538 - Train Accuracy: 0.9906, Validation Accuracy: 0.9737, Loss: 0.0101
# Epoch   7 Batch  300/538 - Train Accuracy: 0.9924, Validation Accuracy: 0.9766, Loss: 0.0087
# Epoch   7 Batch  310/538 - Train Accuracy: 0.9904, Validation Accuracy: 0.9725, Loss: 0.0096
# Epoch   7 Batch  320/538 - Train Accuracy: 0.9872, Validation Accuracy: 0.9743, Loss: 0.0121
# Epoch   7 Batch  330/538 - Train Accuracy: 0.9870, Validation Accuracy: 0.9711, Loss: 0.0110
# Epoch   7 Batch  340/538 - Train Accuracy: 0.9873, Validation Accuracy: 0.9775, Loss: 0.0077
# Epoch   7 Batch  350/538 - Train Accuracy: 0.9927, Validation Accuracy: 0.9700, Loss: 0.0118
# Epoch   7 Batch  360/538 - Train Accuracy: 0.9951, Validation Accuracy: 0.9702, Loss: 0.0076
# Epoch   7 Batch  370/538 - Train Accuracy: 0.9910, Validation Accuracy: 0.9691, Loss: 0.0082
# Epoch   7 Batch  380/538 - Train Accuracy: 0.9918, Validation Accuracy: 0.9739, Loss: 0.0075
# Epoch   7 Batch  390/538 - Train Accuracy: 0.9931, Validation Accuracy: 0.9730, Loss: 0.0071
# Epoch   7 Batch  400/538 - Train Accuracy: 0.9911, Validation Accuracy: 0.9741, Loss: 0.0108
# Epoch   7 Batch  410/538 - Train Accuracy: 0.9898, Validation Accuracy: 0.9700, Loss: 0.0096
# Epoch   7 Batch  420/538 - Train Accuracy: 0.9824, Validation Accuracy: 0.9751, Loss: 0.0111
# Epoch   7 Batch  430/538 - Train Accuracy: 0.9939, Validation Accuracy: 0.9725, Loss: 0.0111
# Epoch   7 Batch  440/538 - Train Accuracy: 0.9908, Validation Accuracy: 0.9775, Loss: 0.0102
# Epoch   7 Batch  450/538 - Train Accuracy: 0.9795, Validation Accuracy: 0.9682, Loss: 0.0137
# Epoch   7 Batch  460/538 - Train Accuracy: 0.9820, Validation Accuracy: 0.9799, Loss: 0.0114
# Epoch   7 Batch  470/538 - Train Accuracy: 0.9833, Validation Accuracy: 0.9782, Loss: 0.0116
# Epoch   7 Batch  480/538 - Train Accuracy: 0.9887, Validation Accuracy: 0.9657, Loss: 0.0104
# Epoch   7 Batch  490/538 - Train Accuracy: 0.9877, Validation Accuracy: 0.9735, Loss: 0.0102
# Epoch   7 Batch  500/538 - Train Accuracy: 0.9940, Validation Accuracy: 0.9672, Loss: 0.0076
# Epoch   7 Batch  510/538 - Train Accuracy: 0.9875, Validation Accuracy: 0.9775, Loss: 0.0094
# Epoch   7 Batch  520/538 - Train Accuracy: 0.9879, Validation Accuracy: 0.9682, Loss: 0.0126
# Epoch   7 Batch  530/538 - Train Accuracy: 0.9850, Validation Accuracy: 0.9698, Loss: 0.0095
# Epoch   8 Batch   10/538 - Train Accuracy: 0.9863, Validation Accuracy: 0.9755, Loss: 0.0109
# Epoch   8 Batch   20/538 - Train Accuracy: 0.9866, Validation Accuracy: 0.9831, Loss: 0.0097
# Epoch   8 Batch   30/538 - Train Accuracy: 0.9895, Validation Accuracy: 0.9815, Loss: 0.0097
# Epoch   8 Batch   40/538 - Train Accuracy: 0.9952, Validation Accuracy: 0.9727, Loss: 0.0090
# Epoch   8 Batch   50/538 - Train Accuracy: 0.9832, Validation Accuracy: 0.9721, Loss: 0.0086
# Epoch   8 Batch   60/538 - Train Accuracy: 0.9889, Validation Accuracy: 0.9769, Loss: 0.0107
# Epoch   8 Batch   70/538 - Train Accuracy: 0.9860, Validation Accuracy: 0.9728, Loss: 0.0074
# Epoch   8 Batch   80/538 - Train Accuracy: 0.9939, Validation Accuracy: 0.9764, Loss: 0.0055
# Epoch   8 Batch   90/538 - Train Accuracy: 0.9823, Validation Accuracy: 0.9755, Loss: 0.0119
# Epoch   8 Batch  100/538 - Train Accuracy: 0.9934, Validation Accuracy: 0.9727, Loss: 0.0076
# Epoch   8 Batch  110/538 - Train Accuracy: 0.9869, Validation Accuracy: 0.9709, Loss: 0.0079
# Epoch   8 Batch  120/538 - Train Accuracy: 0.9939, Validation Accuracy: 0.9785, Loss: 0.0063
# Epoch   8 Batch  130/538 - Train Accuracy: 0.9898, Validation Accuracy: 0.9817, Loss: 0.0088
# Epoch   8 Batch  140/538 - Train Accuracy: 0.9854, Validation Accuracy: 0.9657, Loss: 0.0142
# Epoch   8 Batch  150/538 - Train Accuracy: 0.9939, Validation Accuracy: 0.9743, Loss: 0.0078
# Epoch   8 Batch  160/538 - Train Accuracy: 0.9859, Validation Accuracy: 0.9735, Loss: 0.0098
# Epoch   8 Batch  170/538 - Train Accuracy: 0.9922, Validation Accuracy: 0.9700, Loss: 0.0092
# Epoch   8 Batch  180/538 - Train Accuracy: 0.9836, Validation Accuracy: 0.9638, Loss: 0.0108
# Epoch   8 Batch  190/538 - Train Accuracy: 0.9834, Validation Accuracy: 0.9739, Loss: 0.0131
# Epoch   8 Batch  200/538 - Train Accuracy: 0.9895, Validation Accuracy: 0.9721, Loss: 0.0076
# Epoch   8 Batch  210/538 - Train Accuracy: 0.9888, Validation Accuracy: 0.9689, Loss: 0.0109
# Epoch   8 Batch  220/538 - Train Accuracy: 0.9957, Validation Accuracy: 0.9743, Loss: 0.0117
# Epoch   8 Batch  230/538 - Train Accuracy: 0.9918, Validation Accuracy: 0.9673, Loss: 0.0089
# Epoch   8 Batch  240/538 - Train Accuracy: 0.9822, Validation Accuracy: 0.9656, Loss: 0.0141
# Epoch   8 Batch  250/538 - Train Accuracy: 0.9908, Validation Accuracy: 0.9757, Loss: 0.0081
# Epoch   8 Batch  260/538 - Train Accuracy: 0.9754, Validation Accuracy: 0.9753, Loss: 0.0138
# Epoch   8 Batch  270/538 - Train Accuracy: 0.9934, Validation Accuracy: 0.9824, Loss: 0.0091
# Epoch   8 Batch  280/538 - Train Accuracy: 0.9901, Validation Accuracy: 0.9759, Loss: 0.0080
# Epoch   8 Batch  290/538 - Train Accuracy: 0.9904, Validation Accuracy: 0.9762, Loss: 0.0084
# Epoch   8 Batch  300/538 - Train Accuracy: 0.9955, Validation Accuracy: 0.9846, Loss: 0.0069
# Epoch   8 Batch  310/538 - Train Accuracy: 0.9869, Validation Accuracy: 0.9737, Loss: 0.0092
# Epoch   8 Batch  320/538 - Train Accuracy: 0.9896, Validation Accuracy: 0.9718, Loss: 0.0072
# Epoch   8 Batch  330/538 - Train Accuracy: 0.9892, Validation Accuracy: 0.9741, Loss: 0.0079
# Epoch   8 Batch  340/538 - Train Accuracy: 0.9896, Validation Accuracy: 0.9732, Loss: 0.0103
# Epoch   8 Batch  350/538 - Train Accuracy: 0.9926, Validation Accuracy: 0.9730, Loss: 0.0117
# Epoch   8 Batch  360/538 - Train Accuracy: 0.9877, Validation Accuracy: 0.9748, Loss: 0.0084
# Epoch   8 Batch  370/538 - Train Accuracy: 0.9838, Validation Accuracy: 0.9721, Loss: 0.0096
# Epoch   8 Batch  380/538 - Train Accuracy: 0.9941, Validation Accuracy: 0.9723, Loss: 0.0084
# Epoch   8 Batch  390/538 - Train Accuracy: 0.9911, Validation Accuracy: 0.9696, Loss: 0.0075
# Epoch   8 Batch  400/538 - Train Accuracy: 0.9931, Validation Accuracy: 0.9719, Loss: 0.0068
# Epoch   8 Batch  410/538 - Train Accuracy: 0.9934, Validation Accuracy: 0.9748, Loss: 0.0061
# Epoch   8 Batch  420/538 - Train Accuracy: 0.9910, Validation Accuracy: 0.9750, Loss: 0.0116
# Epoch   8 Batch  430/538 - Train Accuracy: 0.9949, Validation Accuracy: 0.9762, Loss: 0.0097
# Epoch   8 Batch  440/538 - Train Accuracy: 0.9947, Validation Accuracy: 0.9805, Loss: 0.0099
# Epoch   8 Batch  450/538 - Train Accuracy: 0.9868, Validation Accuracy: 0.9693, Loss: 0.0135
# Epoch   8 Batch  460/538 - Train Accuracy: 0.9907, Validation Accuracy: 0.9799, Loss: 0.0088
# Epoch   8 Batch  470/538 - Train Accuracy: 0.9879, Validation Accuracy: 0.9728, Loss: 0.0082
# Epoch   8 Batch  480/538 - Train Accuracy: 0.9888, Validation Accuracy: 0.9762, Loss: 0.0104
# Epoch   8 Batch  490/538 - Train Accuracy: 0.9870, Validation Accuracy: 0.9689, Loss: 0.0079
# Epoch   8 Batch  500/538 - Train Accuracy: 0.9973, Validation Accuracy: 0.9718, Loss: 0.0048
# Epoch   8 Batch  510/538 - Train Accuracy: 0.9892, Validation Accuracy: 0.9785, Loss: 0.0062
# Epoch   8 Batch  520/538 - Train Accuracy: 0.9893, Validation Accuracy: 0.9709, Loss: 0.0094
# Epoch   8 Batch  530/538 - Train Accuracy: 0.9871, Validation Accuracy: 0.9647, Loss: 0.0093
# Epoch   9 Batch   10/538 - Train Accuracy: 0.9885, Validation Accuracy: 0.9748, Loss: 0.0112
# Epoch   9 Batch   20/538 - Train Accuracy: 0.9879, Validation Accuracy: 0.9849, Loss: 0.0105
# Epoch   9 Batch   30/538 - Train Accuracy: 0.9820, Validation Accuracy: 0.9847, Loss: 0.0095
# Epoch   9 Batch   40/538 - Train Accuracy: 0.9908, Validation Accuracy: 0.9828, Loss: 0.0085
# Epoch   9 Batch   50/538 - Train Accuracy: 0.9910, Validation Accuracy: 0.9775, Loss: 0.0099
# Epoch   9 Batch   60/538 - Train Accuracy: 0.9908, Validation Accuracy: 0.9735, Loss: 0.0090
# Epoch   9 Batch   70/538 - Train Accuracy: 0.9950, Validation Accuracy: 0.9769, Loss: 0.0097
# Epoch   9 Batch   80/538 - Train Accuracy: 0.9961, Validation Accuracy: 0.9755, Loss: 0.0077
# Epoch   9 Batch   90/538 - Train Accuracy: 0.9913, Validation Accuracy: 0.9789, Loss: 0.0137
# Epoch   9 Batch  100/538 - Train Accuracy: 0.9854, Validation Accuracy: 0.9796, Loss: 0.0079
# Epoch   9 Batch  110/538 - Train Accuracy: 0.9842, Validation Accuracy: 0.9703, Loss: 0.0095
# Epoch   9 Batch  120/538 - Train Accuracy: 0.9975, Validation Accuracy: 0.9702, Loss: 0.0074
# Epoch   9 Batch  130/538 - Train Accuracy: 0.9959, Validation Accuracy: 0.9703, Loss: 0.0094
# Epoch   9 Batch  140/538 - Train Accuracy: 0.9805, Validation Accuracy: 0.9741, Loss: 0.0121
# Epoch   9 Batch  150/538 - Train Accuracy: 0.9912, Validation Accuracy: 0.9732, Loss: 0.0081
# Epoch   9 Batch  160/538 - Train Accuracy: 0.9883, Validation Accuracy: 0.9767, Loss: 0.0095
# Epoch   9 Batch  170/538 - Train Accuracy: 0.9862, Validation Accuracy: 0.9734, Loss: 0.0087
# Epoch   9 Batch  180/538 - Train Accuracy: 0.9846, Validation Accuracy: 0.9714, Loss: 0.0077
# Epoch   9 Batch  190/538 - Train Accuracy: 0.9939, Validation Accuracy: 0.9732, Loss: 0.0072
# Epoch   9 Batch  200/538 - Train Accuracy: 0.9918, Validation Accuracy: 0.9719, Loss: 0.0074
# Epoch   9 Batch  210/538 - Train Accuracy: 0.9948, Validation Accuracy: 0.9673, Loss: 0.0087
# Epoch   9 Batch  220/538 - Train Accuracy: 0.9900, Validation Accuracy: 0.9714, Loss: 0.0107
# Epoch   9 Batch  230/538 - Train Accuracy: 0.9887, Validation Accuracy: 0.9672, Loss: 0.0089
# Epoch   9 Batch  240/538 - Train Accuracy: 0.9836, Validation Accuracy: 0.9696, Loss: 0.0100
# Epoch   9 Batch  250/538 - Train Accuracy: 0.9898, Validation Accuracy: 0.9792, Loss: 0.0095
# Epoch   9 Batch  260/538 - Train Accuracy: 0.9818, Validation Accuracy: 0.9737, Loss: 0.0117
# Epoch   9 Batch  270/538 - Train Accuracy: 0.9953, Validation Accuracy: 0.9696, Loss: 0.0067
# Epoch   9 Batch  280/538 - Train Accuracy: 0.9892, Validation Accuracy: 0.9654, Loss: 0.0058
# Epoch   9 Batch  290/538 - Train Accuracy: 0.9910, Validation Accuracy: 0.9672, Loss: 0.0097
# Epoch   9 Batch  300/538 - Train Accuracy: 0.9842, Validation Accuracy: 0.9783, Loss: 0.0091
# Epoch   9 Batch  310/538 - Train Accuracy: 0.9877, Validation Accuracy: 0.9757, Loss: 0.0097
# Epoch   9 Batch  320/538 - Train Accuracy: 0.9900, Validation Accuracy: 0.9762, Loss: 0.0089
# Epoch   9 Batch  330/538 - Train Accuracy: 0.9859, Validation Accuracy: 0.9700, Loss: 0.0101
# Epoch   9 Batch  340/538 - Train Accuracy: 0.9912, Validation Accuracy: 0.9732, Loss: 0.0111
# Epoch   9 Batch  350/538 - Train Accuracy: 0.9911, Validation Accuracy: 0.9721, Loss: 0.0102
# Epoch   9 Batch  360/538 - Train Accuracy: 0.9834, Validation Accuracy: 0.9732, Loss: 0.0087
# Epoch   9 Batch  370/538 - Train Accuracy: 0.9879, Validation Accuracy: 0.9698, Loss: 0.0091
# Epoch   9 Batch  380/538 - Train Accuracy: 0.9938, Validation Accuracy: 0.9689, Loss: 0.0062
# Epoch   9 Batch  390/538 - Train Accuracy: 0.9994, Validation Accuracy: 0.9723, Loss: 0.0048
# Epoch   9 Batch  400/538 - Train Accuracy: 0.9918, Validation Accuracy: 0.9735, Loss: 0.0077
# Epoch   9 Batch  410/538 - Train Accuracy: 0.9961, Validation Accuracy: 0.9771, Loss: 0.0065
# Epoch   9 Batch  420/538 - Train Accuracy: 0.9908, Validation Accuracy: 0.9734, Loss: 0.0080
# Epoch   9 Batch  430/538 - Train Accuracy: 0.9777, Validation Accuracy: 0.9771, Loss: 0.0099
# Epoch   9 Batch  440/538 - Train Accuracy: 0.9961, Validation Accuracy: 0.9741, Loss: 0.0075
# Epoch   9 Batch  450/538 - Train Accuracy: 0.9862, Validation Accuracy: 0.9830, Loss: 0.0122
# Epoch   9 Batch  460/538 - Train Accuracy: 0.9874, Validation Accuracy: 0.9794, Loss: 0.0087
# Epoch   9 Batch  470/538 - Train Accuracy: 0.9898, Validation Accuracy: 0.9824, Loss: 0.0087
# Epoch   9 Batch  480/538 - Train Accuracy: 0.9944, Validation Accuracy: 0.9801, Loss: 0.0056
# Epoch   9 Batch  490/538 - Train Accuracy: 0.9866, Validation Accuracy: 0.9776, Loss: 0.0063
# Epoch   9 Batch  500/538 - Train Accuracy: 0.9988, Validation Accuracy: 0.9727, Loss: 0.0046
# Epoch   9 Batch  510/538 - Train Accuracy: 0.9879, Validation Accuracy: 0.9734, Loss: 0.0056
# Epoch   9 Batch  520/538 - Train Accuracy: 0.9904, Validation Accuracy: 0.9769, Loss: 0.0116
# Epoch   9 Batch  530/538 - Train Accuracy: 0.9865, Validation Accuracy: 0.9746, Loss: 0.0078
# Model Trained and Saved

# %% [markdown]
# ### Save Parameters
# Save the `batch_size` and `save_path` parameters for inference.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
# Save parameters for checkpoint
helper.save_params(save_path)

# %% [markdown]
# # Checkpoint

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import tensorflow as tf
import numpy as np
import helper
import problem_unittests as tests

_, (source_vocab_to_int, target_vocab_to_int), (source_int_to_vocab, target_int_to_vocab) = helper.load_preprocess()
load_path = helper.load_params()

# %% [markdown]
# ## Sentence to Sequence
# To feed a sentence into the model for translation, you first need to preprocess it.  Implement the function `sentence_to_seq()` to preprocess new sentences.
#
# - Convert the sentence to lowercase
# - Convert words into ids using `vocab_to_int`
#  - Convert words not in the vocabulary, to the `<UNK>` word id.

# %%
def sentence_to_seq(sentence, vocab_to_int):
    """
    Convert a sentence to a sequence of ids
    :param sentence: String
    :param vocab_to_int: Dictionary to go from the words to an id
    :return: List of word ids
    """
    
    v = vocab_to_int
    lowered = sentence.lower()
    sequence = [v.get(word, v.get('<UNK>')) for word in lowered.split()]
    
    return sequence


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_sentence_to_seq(sentence_to_seq)
# Out:
# Tests Passed

# %% [markdown]
# ## Translate
# This will translate `translate_sentence` from English to French.

# %%
translate_sentence = 'he saw a old yellow truck .'


"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
translate_sentence = sentence_to_seq(translate_sentence, source_vocab_to_int)

loaded_graph = tf.Graph()
with tf.Session(graph=loaded_graph) as sess:
    # Load saved model
    loader = tf.train.import_meta_graph(load_path + '.meta')
    loader.restore(sess, load_path)

    input_data = loaded_graph.get_tensor_by_name('input:0')
    logits = loaded_graph.get_tensor_by_name('predictions:0')
    target_sequence_length = loaded_graph.get_tensor_by_name('target_sequence_length:0')
    source_sequence_length = loaded_graph.get_tensor_by_name('source_sequence_length:0')
    keep_prob = loaded_graph.get_tensor_by_name('keep_prob:0')

    translate_logits = sess.run(logits, {input_data: [translate_sentence]*batch_size,
                                         target_sequence_length: [len(translate_sentence)*2]*batch_size,
                                         source_sequence_length: [len(translate_sentence)]*batch_size,
                                         keep_prob: 1.0})[0]

print('Input')
print('  Word Ids:      {}'.format([i for i in translate_sentence]))
print('  English Words: {}'.format([source_int_to_vocab[i] for i in translate_sentence]))

print('\nPrediction')
print('  Word Ids:      {}'.format([i for i in translate_logits]))
print('  French Words: {}'.format(" ".join([target_int_to_vocab[i] for i in translate_logits])))
# Out:
# INFO:tensorflow:Restoring parameters from checkpoints/dev
# Input
#   Word Ids:      [70, 230, 118, 14, 171, 132, 115]
#   English Words: ['he', 'saw', 'a', 'old', 'yellow', 'truck', '.']
#
# Prediction
#   Word Ids:      [259, 310, 191, 245, 302, 224, 177, 141, 1]
#   French Words: il a vu un vieux camion jaune . <EOS>

# %% [markdown]
# ## Imperfect Translation
# You might notice that some sentences translate better than others.  Since the dataset you're using only has a vocabulary of 227 English words of the thousands that you use, you're only going to see good results using these words.  For this project, you don't need a perfect translation. However, if you want to create a better translation model, you'll need better data.
#
# You can train on the [WMT10 French-English corpus](http://www.statmt.org/wmt10/training-giga-fren.tar).  This dataset has more vocabulary and richer in topics discussed.  However, this will take you days to train, so make sure you've a GPU and the neural network is performing well on dataset we provided.  Just make sure you play with the WMT10 corpus after you've submitted this project.
# ## Submitting This Project
# When submitting this project, make sure to run all the cells before saving the notebook. Save the notebook file as "dlnd_language_translation.ipynb" and save it as a HTML file under "File" -> "Download as". Include the "helper.py" and "problem_unittests.py" files in your submission.
